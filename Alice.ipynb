# %% [markdown]
# # CDC 500 Cities Data:
# More info: https://www.cdc.gov/places/measure-definitions/unhealthy-behaviors/index.html
#
# More data: https://data.cdc.gov/500-Cities-Places/500-Cities-Local-Data-for-Better-Health-2019-relea/6vp6-wxuq
#
# ### Unhealthy Behaviors:
# - Binge driking (Alice): https://data.cdc.gov/resource/gqat-rcqz.json
# - Current smoking
# - No leisure-time physical activity (Esther): https://data.cdc.gov/resource/axqz-rkkp.json
# - Sleeping less than 7 hours (Kent): https://data.cdc.gov/resource/eqbn-8mpz.json
# ### Health Outcomes:
# - Arthritis
# - Asthma
# - High Blood Pressure
# - Cancer
# - High cholesterol
# - Chronic kidney disease
# - Chronic obstructive pulmonary disease
# - Coronary heath disease
# - Depression: https://data.cdc.gov/resource/i2ek-k3pa.json
# - Diagnosed diabetes
# - Obesity
# - All teeth lost among adults aged >= 65
# - Stroke
# ### Use of preventitive services:
# - Current lack of health insurance
# - Visits to doctor for routine checkup within the past year
# - Visits to dentist or dental clinic
# - Taking medicine for high blood pressure control
# - Cholesterol screening
# - Mammography use among women aged 50-74 years
# - Cervical cancer screening among adult women aged 21–65 years
# - Colorectal cancer screening among adults aged 50–75 years
# - Older adults aged ≥65 years who are up to date on a core set of clinical preventive services by sex

# %%
import requests
from pprint import pprint
import pandas as pd

# %%
# 500 Cities: Mental health not good for >=14 days among adults aged >=18 years

mental_url = "https://data.cdc.gov/resource/i2ek-k3pa.json?"
mental_data = requests.get(mental_url).json()
pprint(mental_data)
# Out:
# [{'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0973000',
#   'cityname': 'Stamford',
#   'data_value': '10.0',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '41.1049145013',
#                   'longitude': '-73.5589363142',
#                   'needs_recoding': False},
#   'high_confidence_limit': '10.2',
#   'low_confidence_limit': '9.8',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '122643',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CT',
#   'statedesc': 'Connecticut',
#   'uniqueid': '0973000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '1938595',
#   'cityname': 'Iowa City',
#   'data_value': '13.2',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '41.6558950332',
#                   'longitude': '-91.5308854927',
#                   'needs_recoding': False},
#   'high_confidence_limit': '14.0',
#   'low_confidence_limit': '12.4',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '67862',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'IA',
#   'statedesc': 'Iowa',
#   'uniqueid': '1938595',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '2241155',
#   'cityname': 'Lake Charles',
#   'data_value': '16.6',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '30.2030679966',
#                   'longitude': '-93.2148796496',
#                   'needs_recoding': False},
#   'high_confidence_limit': '16.9',
#   'low_confidence_limit': '16.2',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '71993',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'LA',
#   'statedesc': 'Louisiana',
#   'uniqueid': '2241155',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '2743000',
#   'cityname': 'Minneapolis',
#   'data_value': '11.4',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '44.9635407967',
#                   'longitude': '-93.2678345304',
#                   'needs_recoding': False},
#   'high_confidence_limit': '11.6',
#   'low_confidence_limit': '11.3',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '382578',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'MN',
#   'statedesc': 'Minnesota',
#   'uniqueid': '2743000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '2754880',
#   'cityname': 'Rochester',
#   'data_value': '10.1',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '44.0150574384',
#                   'longitude': '-92.4775005494',
#                   'needs_recoding': False},
#   'high_confidence_limit': '10.3',
#   'low_confidence_limit': '9.8',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '106769',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'MN',
#   'statedesc': 'Minnesota',
#   'uniqueid': '2754880',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '3268400',
#   'cityname': 'Sparks',
#   'data_value': '14.1',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '39.573373276',
#                   'longitude': '-119.713134168',
#                   'needs_recoding': False},
#   'high_confidence_limit': '14.4',
#   'low_confidence_limit': '13.9',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '90264',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'NV',
#   'statedesc': 'Nevada',
#   'uniqueid': '3268400',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '3651000',
#   'cityname': 'New York',
#   'data_value': '20.3',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '40.8260142033',
#                   'longitude': '-73.8879212606',
#                   'needs_recoding': False},
#   'high_confidence_limit': '22.2',
#   'low_confidence_limit': '18.2',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '1631',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'NY',
#   'statedesc': 'New York',
#   'tractfips': '36005012102',
#   'uniqueid': '3651000-36005012102',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '3651000',
#   'cityname': 'New York',
#   'data_value': '14.8',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '40.6802873154',
#                   'longitude': '-73.9138395394',
#                   'needs_recoding': False},
#   'high_confidence_limit': '16.5',
#   'low_confidence_limit': '13.0',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '4120',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'NY',
#   'statedesc': 'New York',
#   'tractfips': '36047037100',
#   'uniqueid': '3651000-36047037100',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '3651000',
#   'cityname': 'New York',
#   'data_value': '13.4',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '40.6827365098',
#                   'longitude': '-73.8837649686',
#                   'needs_recoding': False},
#   'high_confidence_limit': '14.6',
#   'low_confidence_limit': '12.1',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '3907',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'NY',
#   'statedesc': 'New York',
#   'tractfips': '36047117202',
#   'uniqueid': '3651000-36047117202',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '3651000',
#   'cityname': 'New York',
#   'data_value': '9.2',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '40.7925561737',
#                   'longitude': '-73.9677460289',
#                   'needs_recoding': False},
#   'high_confidence_limit': '10.2',
#   'low_confidence_limit': '8.4',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '8866',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'NY',
#   'statedesc': 'New York',
#   'tractfips': '36061018100',
#   'uniqueid': '3651000-36061018100',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '3651000',
#   'cityname': 'New York',
#   'data_value': '13.1',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '40.6902842572',
#                   'longitude': '-73.8520187104',
#                   'needs_recoding': False},
#   'high_confidence_limit': '14.2',
#   'low_confidence_limit': '11.9',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '2931',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'NY',
#   'statedesc': 'New York',
#   'tractfips': '36081001800',
#   'uniqueid': '3651000-36081001800',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '3651000',
#   'cityname': 'New York',
#   'data_value': '11.2',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '40.7600344521',
#                   'longitude': '-73.9175932729',
#                   'needs_recoding': False},
#   'high_confidence_limit': '12.4',
#   'low_confidence_limit': '10.1',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '2251',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'NY',
#   'statedesc': 'New York',
#   'tractfips': '36081015500',
#   'uniqueid': '3651000-36081015500',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '3651000',
#   'cityname': 'New York',
#   'data_value': '16.1',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '40.6860784883',
#                   'longitude': '-73.7829526832',
#                   'needs_recoding': False},
#   'high_confidence_limit': '17.7',
#   'low_confidence_limit': '14.6',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '2256',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'NY',
#   'statedesc': 'New York',
#   'tractfips': '36081027800',
#   'uniqueid': '3651000-36081027800',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '3651000',
#   'cityname': 'New York',
#   'data_value': '10.0',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '40.7448570957',
#                   'longitude': '-73.7821667144',
#                   'needs_recoding': False},
#   'high_confidence_limit': '11.0',
#   'low_confidence_limit': '9.0',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '2603',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'NY',
#   'statedesc': 'New York',
#   'tractfips': '36081140902',
#   'uniqueid': '3651000-36081140902',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '4260000',
#   'cityname': 'Philadelphia',
#   'data_value': '19.5',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '39.9194134199',
#                   'longitude': '-75.2335256208',
#                   'needs_recoding': False},
#   'high_confidence_limit': '21.6',
#   'low_confidence_limit': '17.7',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '4524',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'PA',
#   'statedesc': 'Pennsylvania',
#   'tractfips': '42101006200',
#   'uniqueid': '4260000-42101006200',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '3755000',
#   'cityname': 'Raleigh',
#   'data_value': '19.5',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '35.7880127629',
#                   'longitude': '-78.6883157431',
#                   'needs_recoding': False},
#   'high_confidence_limit': '21.5',
#   'low_confidence_limit': '17.3',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '4696',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'NC',
#   'statedesc': 'North Carolin',
#   'tractfips': '37183051101',
#   'uniqueid': '3755000-37183051101',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '3825700',
#   'cityname': 'Fargo',
#   'data_value': '10.9',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '46.8411884916',
#                   'longitude': '-96.7911298785',
#                   'needs_recoding': False},
#   'high_confidence_limit': '12.4',
#   'low_confidence_limit': '9.6',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '2780',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'ND',
#   'statedesc': 'North Dakota',
#   'tractfips': '38017001002',
#   'uniqueid': '3825700-38017001002',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '3901000',
#   'cityname': 'Akron',
#   'data_value': '20.0',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '41.0493532602',
#                   'longitude': '-81.4838908858',
#                   'needs_recoding': False},
#   'high_confidence_limit': '21.5',
#   'low_confidence_limit': '18.6',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '3739',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'OH',
#   'statedesc': 'Ohio',
#   'tractfips': '39153503500',
#   'uniqueid': '3901000-39153503500',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '3915000',
#   'cityname': 'Cincinnati',
#   'data_value': '21.8',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '39.1113516599',
#                   'longitude': '-84.5582974446',
#                   'needs_recoding': False},
#   'high_confidence_limit': '23.4',
#   'low_confidence_limit': '20.3',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '2848',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'OH',
#   'statedesc': 'Ohio',
#   'tractfips': '39061009300',
#   'uniqueid': '3915000-39061009300',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '3918000',
#   'cityname': 'Columbus',
#   'data_value': '19.1',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '40.0163005764',
#                   'longitude': '-82.962752876',
#                   'needs_recoding': False},
#   'high_confidence_limit': '20.5',
#   'low_confidence_limit': '17.8',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '2069',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'OH',
#   'statedesc': 'Ohio',
#   'tractfips': '39049000920',
#   'uniqueid': '3918000-39049000920',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '3918000',
#   'cityname': 'Columbus',
#   'data_value': '9.1',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '40.104695724',
#                   'longitude': '-83.0454390047',
#                   'needs_recoding': False},
#   'high_confidence_limit': '10.1',
#   'low_confidence_limit': '8.3',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '3445',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'OH',
#   'statedesc': 'Ohio',
#   'tractfips': '39049006392',
#   'uniqueid': '3918000-39049006392',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '3921000',
#   'cityname': 'Dayton',
#   'data_value': '26.2',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '39.7605587396',
#                   'longitude': '-84.2840777168',
#                   'needs_recoding': False},
#   'high_confidence_limit': '31.0',
#   'low_confidence_limit': '20.3',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '396',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'OH',
#   'statedesc': 'Ohio',
#   'tractfips': '39113070201',
#   'uniqueid': '3921000-39113070201',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '4023200',
#   'cityname': 'Edmond',
#   'data_value': '11.5',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '35.6600017377',
#                   'longitude': '-97.4415333723',
#                   'needs_recoding': False},
#   'high_confidence_limit': '13.1',
#   'low_confidence_limit': '10.2',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '4367',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'OK',
#   'statedesc': 'Oklahoma',
#   'tractfips': '40109108114',
#   'uniqueid': '4023200-40109108114',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '4052500',
#   'cityname': 'Norman',
#   'data_value': '18.0',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '35.211099712',
#                   'longitude': '-97.4148339775',
#                   'needs_recoding': False},
#   'high_confidence_limit': '20.3',
#   'low_confidence_limit': '15.7',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '6203',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'OK',
#   'statedesc': 'Oklahoma',
#   'tractfips': '40027200601',
#   'uniqueid': '4052500-40027200601',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '4055000',
#   'cityname': 'Oklahoma City',
#   'data_value': '15.6',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '35.467564288',
#                   'longitude': '-97.5137615524',
#                   'needs_recoding': False},
#   'high_confidence_limit': '15.7',
#   'low_confidence_limit': '15.5',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '579999',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'OK',
#   'statedesc': 'Oklahoma',
#   'uniqueid': '4055000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '4835000',
#   'cityname': 'Houston',
#   'data_value': '11.4',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '29.6696144087',
#                   'longitude': '-95.5174643659',
#                   'needs_recoding': False},
#   'high_confidence_limit': '12.4',
#   'low_confidence_limit': '10.5',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '3701',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'TX',
#   'statedesc': 'Texas',
#   'tractfips': '48201423301',
#   'uniqueid': '4835000-48201423301',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '4835000',
#   'cityname': 'Houston',
#   'data_value': '13.4',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '29.8910779332',
#                   'longitude': '-95.4176742781',
#                   'needs_recoding': False},
#   'high_confidence_limit': '14.5',
#   'low_confidence_limit': '12.3',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '4362',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'TX',
#   'statedesc': 'Texas',
#   'tractfips': '48201533500',
#   'uniqueid': '4835000-48201533500',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '4261000',
#   'cityname': 'Pittsburgh',
#   'data_value': '12.2',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '40.4520308556',
#                   'longitude': '-79.9419482635',
#                   'needs_recoding': False},
#   'high_confidence_limit': '13.6',
#   'low_confidence_limit': '11.0',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '4934',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'PA',
#   'statedesc': 'Pennsylvania',
#   'tractfips': '42003070900',
#   'uniqueid': '4261000-42003070900',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '4516000',
#   'cityname': 'Columbia',
#   'data_value': '25.0',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '34.0863737449',
#                   'longitude': '-80.9840993264',
#                   'needs_recoding': False},
#   'high_confidence_limit': '27.0',
#   'low_confidence_limit': '23.1',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '555',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'SC',
#   'statedesc': 'South Carolin',
#   'tractfips': '45079010806',
#   'uniqueid': '4516000-45079010806',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '4740000',
#   'cityname': 'Knoxville',
#   'data_value': '11.6',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '35.8932992399',
#                   'longitude': '-84.1172044713',
#                   'needs_recoding': False},
#   'high_confidence_limit': '13.9',
#   'low_confidence_limit': '9.9',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '259',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'TN',
#   'statedesc': 'Tennessee',
#   'tractfips': '47093005807',
#   'uniqueid': '4740000-47093005807',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '4748000',
#   'cityname': 'Memphis',
#   'data_value': '17.2',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '35.1529878945',
#                   'longitude': '-89.9740999194',
#                   'needs_recoding': False},
#   'high_confidence_limit': '18.8',
#   'low_confidence_limit': '15.5',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '1745',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'TN',
#   'statedesc': 'Tennessee',
#   'tractfips': '47157001500',
#   'uniqueid': '4748000-47157001500',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '4748000',
#   'cityname': 'Memphis',
#   'data_value': '15.2',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '35.0549233988',
#                   'longitude': '-89.8505914096',
#                   'needs_recoding': False},
#   'high_confidence_limit': '16.9',
#   'low_confidence_limit': '13.4',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '4156',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'TN',
#   'statedesc': 'Tennessee',
#   'tractfips': '47157021726',
#   'uniqueid': '4748000-47157021726',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '4801000',
#   'cityname': 'Abilene',
#   'data_value': '14.4',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '32.4421216752',
#                   'longitude': '-99.7789778963',
#                   'needs_recoding': False},
#   'high_confidence_limit': '15.5',
#   'low_confidence_limit': '13.2',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '4604',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'TX',
#   'statedesc': 'Texas',
#   'tractfips': '48441011400',
#   'uniqueid': '4801000-48441011400',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '4803000',
#   'cityname': 'Amarillo',
#   'data_value': '12.5',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '35.1542150182',
#                   'longitude': '-101.893130112',
#                   'needs_recoding': False},
#   'high_confidence_limit': '13.6',
#   'low_confidence_limit': '11.4',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '5288',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'TX',
#   'statedesc': 'Texas',
#   'tractfips': '48381021300',
#   'uniqueid': '4803000-48381021300',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '4819972',
#   'cityname': 'Denton',
#   'data_value': '19.2',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.2054852962',
#                   'longitude': '-97.1567798218',
#                   'needs_recoding': False},
#   'high_confidence_limit': '21.5',
#   'low_confidence_limit': '16.9',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '4644',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'TX',
#   'statedesc': 'Texas',
#   'tractfips': '48121020900',
#   'uniqueid': '4819972-48121020900',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '4824000',
#   'cityname': 'El Paso',
#   'data_value': '12.2',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '31.7769136374',
#                   'longitude': '-106.330045275',
#                   'needs_recoding': False},
#   'high_confidence_limit': '13.6',
#   'low_confidence_limit': '10.9',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '6366',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'TX',
#   'statedesc': 'Texas',
#   'tractfips': '48141010307',
#   'uniqueid': '4824000-48141010307',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '4827000',
#   'cityname': 'Fort Worth',
#   'data_value': '17.8',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '32.7304179149',
#                   'longitude': '-97.2168205461',
#                   'needs_recoding': False},
#   'high_confidence_limit': '18.7',
#   'low_confidence_limit': '17.0',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '2801',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'TX',
#   'statedesc': 'Texas',
#   'tractfips': '48439101302',
#   'uniqueid': '4827000-48439101302',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '4827000',
#   'cityname': 'Fort Worth',
#   'data_value': '13.1',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '32.636015222',
#                   'longitude': '-97.4028786384',
#                   'needs_recoding': False},
#   'high_confidence_limit': '13.8',
#   'low_confidence_limit': '12.3',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '7660',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'TX',
#   'statedesc': 'Texas',
#   'tractfips': '48439105510',
#   'uniqueid': '4827000-48439105510',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '4829000',
#   'cityname': 'Garland',
#   'data_value_footnote': 'Estimates suppressed for population less than 50',
#   'data_value_footnote_symbol': '*',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '32.967610286',
#                   'longitude': '-96.5292305893',
#                   'needs_recoding': False},
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '23',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'TX',
#   'statedesc': 'Texas',
#   'tractfips': '48113018122',
#   'uniqueid': '4829000-48113018122',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '4865000',
#   'cityname': 'San Antonio',
#   'data_value': '11.5',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '29.5250503802',
#                   'longitude': '-98.6250842174',
#                   'needs_recoding': False},
#   'high_confidence_limit': '12.5',
#   'low_confidence_limit': '10.6',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '4917',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'TX',
#   'statedesc': 'Texas',
#   'tractfips': '48029181822',
#   'uniqueid': '4865000-48029181822',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '4957300',
#   'cityname': 'Orem',
#   'data_value': '12.4',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '40.2987127625',
#                   'longitude': '-111.699188517',
#                   'needs_recoding': False},
#   'high_confidence_limit': '12.7',
#   'low_confidence_limit': '12.0',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '88328',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'UT',
#   'statedesc': 'Utah',
#   'uniqueid': '4957300',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '4967440',
#   'cityname': 'Sandy',
#   'data_value_footnote': 'Estimates suppressed for population less than 50',
#   'data_value_footnote_symbol': '*',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '40.6107326458',
#                   'longitude': '-111.863830053',
#                   'needs_recoding': False},
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '30',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'UT',
#   'statedesc': 'Utah',
#   'tractfips': '49035112502',
#   'uniqueid': '4967440-49035112502',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '5303180',
#   'cityname': 'Auburn',
#   'data_value': '12.4',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '47.2508383545',
#                   'longitude': '-122.201284574',
#                   'needs_recoding': False},
#   'high_confidence_limit': '13.7',
#   'low_confidence_limit': '11.2',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '2222',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'tractfips': '53053070315',
#   'uniqueid': '5303180-53053070315',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '5357745',
#   'cityname': 'Renton',
#   'data_value': '11.5',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '47.509688489',
#                   'longitude': '-122.184790916',
#                   'needs_recoding': False},
#   'high_confidence_limit': '12.6',
#   'low_confidence_limit': '10.4',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '7430',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'tractfips': '53033025200',
#   'uniqueid': '5357745-53033025200',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '5367000',
#   'cityname': 'Spokane',
#   'data_value': '15.3',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '47.6736243259',
#                   'longitude': '-117.415973291',
#                   'needs_recoding': False},
#   'high_confidence_limit': '15.6',
#   'low_confidence_limit': '15.1',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '208916',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5367000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '5380010',
#   'cityname': 'Yakima',
#   'data_value': '16.0',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '46.5925792092',
#                   'longitude': '-120.547807614',
#                   'needs_recoding': False},
#   'high_confidence_limit': '16.4',
#   'low_confidence_limit': '15.7',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '91067',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5380010',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '5414600',
#   'cityname': 'Charleston',
#   'data_value': '11.6',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '38.3263390517',
#                   'longitude': '-81.6432548861',
#                   'needs_recoding': False},
#   'high_confidence_limit': '13.2',
#   'low_confidence_limit': '10.1',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '3182',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'WV',
#   'statedesc': 'West Virginia',
#   'tractfips': '54039001902',
#   'uniqueid': '5414600-54039001902',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '5548000',
#   'cityname': 'Madison',
#   'data_value': '9.8',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '43.0352956985',
#                   'longitude': '-89.4718115164',
#                   'needs_recoding': False},
#   'high_confidence_limit': '10.8',
#   'low_confidence_limit': '8.7',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '4182',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'WI',
#   'statedesc': 'Wisconsin',
#   'tractfips': '55025000501',
#   'uniqueid': '5548000-55025000501',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '5548000',
#   'cityname': 'Madison',
#   'data_value': '10.8',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '43.0729164238',
#                   'longitude': '-89.3860992228',
#                   'needs_recoding': False},
#   'high_confidence_limit': '12.5',
#   'low_confidence_limit': '9.3',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '3434',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'WI',
#   'statedesc': 'Wisconsin',
#   'tractfips': '55025001704',
#   'uniqueid': '5548000-55025001704',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0107000',
#   'cityname': 'Birmingham',
#   'data_value': '18.8',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.5372993423',
#                   'longitude': '-86.8036590482',
#                   'needs_recoding': False},
#   'high_confidence_limit': '20.5',
#   'low_confidence_limit': '17.0',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '3390',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AL',
#   'statedesc': 'Alabama',
#   'tractfips': '01073001600',
#   'uniqueid': '0107000-01073001600',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0203000',
#   'cityname': 'Anchorage',
#   'data_value': '12.2',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '61.2177091891',
#                   'longitude': '-149.891260329',
# ...
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.8440749154',
#                   'longitude': '-117.858654218',
#                   'needs_recoding': False},
#   'high_confidence_limit': '15.2',
#   'low_confidence_limit': '12.8',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '6488',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'tractfips': '06059086407',
#   'uniqueid': '0602000-06059086407',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0477000',
#   'cityname': 'Tucson',
#   'data_value': '13.9',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '32.2647272404',
#                   'longitude': '-110.903384301',
#                   'needs_recoding': False},
#   'high_confidence_limit': '15.3',
#   'low_confidence_limit': '12.6',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '4325',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'tractfips': '04019002905',
#   'uniqueid': '0477000-04019002905',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0541000',
#   'cityname': 'Little Rock',
#   'data_value': '15.8',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '34.7067108009',
#                   'longitude': '-92.1828530354',
#                   'needs_recoding': False},
#   'high_confidence_limit': '17.0',
#   'low_confidence_limit': '14.6',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '881',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AR',
#   'statedesc': 'Arkansas',
#   'tractfips': '05119004007',
#   'uniqueid': '0541000-05119004007',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0600884',
#   'cityname': 'Alhambra',
#   'data_value': '11.1',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '34.0802793151',
#                   'longitude': '-118.139020746',
#                   'needs_recoding': False},
#   'high_confidence_limit': '12.2',
#   'low_confidence_limit': '10.0',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '4218',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'tractfips': '06037480902',
#   'uniqueid': '0600884-06037480902',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0477000',
#   'cityname': 'Tucson',
#   'data_value': '18.2',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '32.243499728',
#                   'longitude': '-110.995688433',
#                   'needs_recoding': False},
#   'high_confidence_limit': '19.4',
#   'low_confidence_limit': '16.9',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '3791',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'tractfips': '04019001200',
#   'uniqueid': '0477000-04019001200',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0477000',
#   'cityname': 'Tucson',
#   'data_value': '17.3',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '32.1554438561',
#                   'longitude': '-111.000104979',
#                   'needs_recoding': False},
#   'high_confidence_limit': '18.7',
#   'low_confidence_limit': '15.8',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '6534',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'tractfips': '04019002505',
#   'uniqueid': '0477000-04019002505',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0465000',
#   'cityname': 'Scottsdale',
#   'data_value': '6.8',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.5110510427',
#                   'longitude': '-111.935811236',
#                   'needs_recoding': False},
#   'high_confidence_limit': '7.7',
#   'low_confidence_limit': '6.1',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '201',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'tractfips': '04013105002',
#   'uniqueid': '0465000-04013105002',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0523290',
#   'cityname': 'Fayetteville',
#   'data_value': '11.8',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '36.0924487571',
#                   'longitude': '-94.139476179',
#                   'needs_recoding': False},
#   'high_confidence_limit': '13.4',
#   'low_confidence_limit': '10.3',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '5571',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AR',
#   'statedesc': 'Arkansas',
#   'tractfips': '05143010107',
#   'uniqueid': '0523290-05143010107',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0600562',
#   'cityname': 'Alameda',
#   'data_value': '8.6',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '37.7331115628',
#                   'longitude': '-122.241211914',
#                   'needs_recoding': False},
#   'high_confidence_limit': '9.4',
#   'low_confidence_limit': '7.8',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '6526',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'tractfips': '06001428301',
#   'uniqueid': '0600562-06001428301',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0477000',
#   'cityname': 'Tucson',
#   'data_value': '9.9',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '32.2439334602',
#                   'longitude': '-110.803875435',
#                   'needs_recoding': False},
#   'high_confidence_limit': '11.2',
#   'low_confidence_limit': '8.7',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '2891',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'tractfips': '04019004047',
#   'uniqueid': '0477000-04019004047',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0602000',
#   'cityname': 'Anaheim',
#   'data_value': '14.6',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.8361368106',
#                   'longitude': '-117.911084312',
#                   'needs_recoding': False},
#   'high_confidence_limit': '16.2',
#   'low_confidence_limit': '13.0',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '10413',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'tractfips': '06059087300',
#   'uniqueid': '0602000-06059087300',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0523290',
#   'cityname': 'Fayetteville',
#   'data_value': '16.5',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '36.0376376413',
#                   'longitude': '-94.1228698771',
#                   'needs_recoding': False},
#   'high_confidence_limit': '18.0',
#   'low_confidence_limit': '14.9',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '2407',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AR',
#   'statedesc': 'Arkansas',
#   'tractfips': '05143011102',
#   'uniqueid': '0523290-05143011102',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0465000',
#   'cityname': 'Scottsdale',
#   'data_value': '8.4',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.677327818',
#                   'longitude': '-111.838259128',
#                   'needs_recoding': False},
#   'high_confidence_limit': '9.7',
#   'low_confidence_limit': '7.4',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '4143',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'tractfips': '04013216851',
#   'uniqueid': '0465000-04013216851',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0477000',
#   'cityname': 'Tucson',
#   'data_value': '10.8',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '32.2202432277',
#                   'longitude': '-110.920463268',
#                   'needs_recoding': False},
#   'high_confidence_limit': '12.3',
#   'low_confidence_limit': '9.6',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '3698',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'tractfips': '04019001900',
#   'uniqueid': '0477000-04019001900',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0471510',
#   'cityname': 'Surprise',
#   'data_value': '12.9',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.6315935877',
#                   'longitude': '-112.418112736',
#                   'needs_recoding': False},
#   'high_confidence_limit': '14.3',
#   'low_confidence_limit': '11.6',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '5458',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'tractfips': '04013061026',
#   'uniqueid': '0471510-04013061026',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0465000',
#   'cityname': 'Scottsdale',
#   'data_value': '10.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.6872493651',
#                   'longitude': '-111.865085877',
#                   'needs_recoding': False},
#   'high_confidence_limit': '10.6',
#   'low_confidence_limit': '10.3',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '217385',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0465000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0600562',
#   'cityname': 'Alameda',
#   'data_value': '9.9',
#   'data_value_type': 'Crude prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'CrdPrv',
#   'geographiclevel': 'Census Tract',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '37.7714922387',
#                   'longitude': '-122.269058188',
#                   'needs_recoding': False},
#   'high_confidence_limit': '10.9',
#   'low_confidence_limit': '8.9',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '4640',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'tractfips': '06001427800',
#   'uniqueid': '0600562-06001427800',
#   'year': '2017'}]

# %%
print(len(mental_data))
# Out:
# 1000

# %%
# Load in the data
mental_url = "https://data.cdc.gov/resource/i2ek-k3pa.json?GeographicLevel=City&DataValueTypeID=AgeAdjPrv"
mental_data = requests.get(mental_url).json()
print(len(mental_data))
# Out:
# 500

# %%
# Create the dataframe
mental_df = pd.DataFrame()
mental_df['City Name'] = ""
mental_df['Lat'] = ""
mental_df['Lon'] = ""
mental_df['Value'] = ""
mental_df['State'] = ""
mental_df
# Out:
# Empty DataFrame
# Columns: [City Name, Lat, Lon, Value, State]
# Index: []

# %%
# Add values to dataframe

for x in range(len(mental_data)):
    mental_df.loc[x,'City Name'] = mental_data[x]['cityname']
    mental_df.loc[x,'Lat'] = mental_data[x]['geolocation']['latitude']
    mental_df.loc[x,'Lon'] = mental_data[x]['geolocation']['longitude']
    mental_df.loc[x, 'Value'] = mental_data[x]['data_value']
    mental_df.loc[x, 'State'] = mental_data[x]['stateabbr']

mental_df.head()
# Out:
#     City Name            Lat             Lon Value State
# 0      Mobile  30.6776248648  -88.1184482714  16.3    AL
# 1     Gilbert   33.310149392  -111.746237467  10.9    AZ
# 2    Avondale  33.3858367405  -112.323626619  13.5    AZ
# 3  Montgomery  32.3472645333  -86.2677059552  15.8    AL
# 4   Anchorage   61.149868731  -149.111113424  11.0    AK
