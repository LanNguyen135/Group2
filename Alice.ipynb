# %% [markdown]
# # CDC 500 Cities Data:
# More info: https://www.cdc.gov/places/measure-definitions/unhealthy-behaviors/index.html
#
# More data: https://data.cdc.gov/500-Cities-Places/500-Cities-Local-Data-for-Better-Health-2019-relea/6vp6-wxuq
#
# ### Unhealthy Behaviors:
# - Binge driking (Alice): https://data.cdc.gov/resource/gqat-rcqz.json
# - Current smoking
# - No leisure-time physical activity (Esther): https://data.cdc.gov/resource/axqz-rkkp.json
# - Sleeping less than 7 hours (Kent): https://data.cdc.gov/resource/eqbn-8mpz.json
# ### Health Outcomes:
# - Arthritis
# - Asthma
# - High Blood Pressure
# - Cancer
# - High cholesterol
# - Chronic kidney disease
# - Chronic obstructive pulmonary disease
# - Coronary heath disease
# - Depression: https://data.cdc.gov/resource/i2ek-k3pa.json
# - Diagnosed diabetes
# - Obesity
# - All teeth lost among adults aged >= 65
# - Stroke
# ### Use of preventitive services:
# - Current lack of health insurance
# - Visits to doctor for routine checkup within the past year
# - Visits to dentist or dental clinic
# - Taking medicine for high blood pressure control
# - Cholesterol screening
# - Mammography use among women aged 50-74 years
# - Cervical cancer screening among adult women aged 21–65 years
# - Colorectal cancer screening among adults aged 50–75 years
# - Older adults aged ≥65 years who are up to date on a core set of clinical preventive services by sex

# %%
# pip install selenium
import requests
from pprint import pprint
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
import hvplot.pandas
import json

# %%
# Import mental health data
mental_base_url = "https://data.cdc.gov/resource/i2ek-k3pa.json?"
params = {
    "GeographicLevel" : "City",
    "DataValueTypeID" : "AgeAdjPrv"
}
mental_data = requests.get(mental_base_url, params = params).json()
pprint(mental_data)
# Out:
# [{'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0150000',
#   'cityname': 'Mobile',
#   'data_value': '16.3',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '30.6776248648',
#                   'longitude': '-88.1184482714',
#                   'needs_recoding': False},
#   'high_confidence_limit': '16.5',
#   'low_confidence_limit': '16.2',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '195111',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AL',
#   'statedesc': 'Alabama',
#   'uniqueid': '0150000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0427400',
#   'cityname': 'Gilbert',
#   'data_value': '10.9',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.310149392',
#                   'longitude': '-111.746237467',
#                   'needs_recoding': False},
#   'high_confidence_limit': '11.0',
#   'low_confidence_limit': '10.7',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '208453',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0427400',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0404720',
#   'cityname': 'Avondale',
#   'data_value': '13.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.3858367405',
#                   'longitude': '-112.323626619',
#                   'needs_recoding': False},
#   'high_confidence_limit': '13.8',
#   'low_confidence_limit': '13.3',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '76238',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0404720',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0151000',
#   'cityname': 'Montgomery',
#   'data_value': '15.8',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '32.3472645333',
#                   'longitude': '-86.2677059552',
#                   'needs_recoding': False},
#   'high_confidence_limit': '16.1',
#   'low_confidence_limit': '15.6',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '205764',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AL',
#   'statedesc': 'Alabama',
#   'uniqueid': '0151000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0203000',
#   'cityname': 'Anchorage',
#   'data_value': '11.0',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '61.149868731',
#                   'longitude': '-149.111113424',
#                   'needs_recoding': False},
#   'high_confidence_limit': '11.2',
#   'low_confidence_limit': '10.9',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '291826',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AK',
#   'statedesc': 'Alaska',
#   'uniqueid': '0203000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0455000',
#   'cityname': 'Phoenix',
#   'data_value': '13.9',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.5724138695',
#                   'longitude': '-112.088995222',
#                   'needs_recoding': False},
#   'high_confidence_limit': '13.9',
#   'low_confidence_limit': '13.8',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '1445632',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0455000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0446000',
#   'cityname': 'Mesa',
#   'data_value': '13.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.4022837359',
#                   'longitude': '-111.718721181',
#                   'needs_recoding': False},
#   'high_confidence_limit': '13.7',
#   'low_confidence_limit': '13.4',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '439041',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0446000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0454050',
#   'cityname': 'Peoria',
#   'data_value': '12.2',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.7847206422',
#                   'longitude': '-112.298680584',
#                   'needs_recoding': False},
#   'high_confidence_limit': '12.4',
#   'low_confidence_limit': '12.0',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '154065',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0454050',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0471510',
#   'cityname': 'Surprise',
#   'data_value': '12.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.6803835177',
#                   'longitude': '-112.452218439',
#                   'needs_recoding': False},
#   'high_confidence_limit': '12.8',
#   'low_confidence_limit': '12.2',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '117517',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0471510',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0566080',
#   'cityname': 'Springdale',
#   'data_value': '16.0',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '36.1869932598',
#                   'longitude': '-94.1536274531',
#                   'needs_recoding': False},
#   'high_confidence_limit': '16.4',
#   'low_confidence_limit': '15.6',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '69797',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AR',
#   'statedesc': 'Arkansas',
#   'uniqueid': '0566080',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0602000',
#   'cityname': 'Anaheim',
#   'data_value': '12.6',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.8389076996',
#                   'longitude': '-117.857613481',
#                   'needs_recoding': False},
#   'high_confidence_limit': '12.8',
#   'low_confidence_limit': '12.5',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '336265',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0602000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0485540',
#   'cityname': 'Yuma',
#   'data_value': '13.6',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '32.5986027117',
#                   'longitude': '-114.54836837',
#                   'needs_recoding': False},
#   'high_confidence_limit': '13.9',
#   'low_confidence_limit': '13.4',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '93064',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0485540',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0535710',
#   'cityname': 'Jonesboro',
#   'data_value': '15.3',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '35.8208121538',
#                   'longitude': '-90.6794991686',
#                   'needs_recoding': False},
#   'high_confidence_limit': '15.8',
#   'low_confidence_limit': '14.9',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '67263',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AR',
#   'statedesc': 'Arkansas',
#   'uniqueid': '0535710',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0523290',
#   'cityname': 'Fayetteville',
#   'data_value': '14.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '36.0712117312',
#                   'longitude': '-94.1659600436',
#                   'needs_recoding': False},
#   'high_confidence_limit': '14.6',
#   'low_confidence_limit': '13.7',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '73580',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AR',
#   'statedesc': 'Arkansas',
#   'uniqueid': '0523290',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0524550',
#   'cityname': 'Fort Smith',
#   'data_value': '17.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '35.3491692636',
#                   'longitude': '-94.3696317306',
#                   'needs_recoding': False},
#   'high_confidence_limit': '17.4',
#   'low_confidence_limit': '16.8',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '86209',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AR',
#   'statedesc': 'Arkansas',
#   'uniqueid': '0524550',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0541000',
#   'cityname': 'Little Rock',
#   'data_value': '13.3',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '34.7253957894',
#                   'longitude': '-92.3583751863',
#                   'needs_recoding': False},
#   'high_confidence_limit': '13.5',
#   'low_confidence_limit': '13.1',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '193524',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AR',
#   'statedesc': 'Arkansas',
#   'uniqueid': '0541000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0602252',
#   'cityname': 'Antioch',
#   'data_value': '13.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '37.9777042922',
#                   'longitude': '-121.796606971',
#                   'needs_recoding': False},
#   'high_confidence_limit': '13.8',
#   'low_confidence_limit': '13.3',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '102372',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0602252',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0465000',
#   'cityname': 'Scottsdale',
#   'data_value': '10.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.6872493651',
#                   'longitude': '-111.865085877',
#                   'needs_recoding': False},
#   'high_confidence_limit': '10.6',
#   'low_confidence_limit': '10.3',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '217385',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0465000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0600562',
#   'cityname': 'Alameda',
#   'data_value': '10.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '37.7650849031',
#                   'longitude': '-122.266489842',
#                   'needs_recoding': False},
#   'high_confidence_limit': '10.4',
#   'low_confidence_limit': '9.8',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '73812',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0600562',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0473000',
#   'cityname': 'Tempe',
#   'data_value': '12.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.3882640307',
#                   'longitude': '-111.931802302',
#                   'needs_recoding': False},
#   'high_confidence_limit': '12.7',
#   'low_confidence_limit': '12.3',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '161719',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0473000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0600884',
#   'cityname': 'Alhambra',
#   'data_value': '10.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '34.0839734383',
#                   'longitude': '-118.135514119',
#                   'needs_recoding': False},
#   'high_confidence_limit': '10.4',
#   'low_confidence_limit': '9.9',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '83089',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0600884',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0477000',
#   'cityname': 'Tucson',
#   'data_value': '14.4',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '32.1567244483',
#                   'longitude': '-110.877085494',
#                   'needs_recoding': False},
#   'high_confidence_limit': '14.6',
#   'low_confidence_limit': '14.3',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '520116',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0477000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0606000',
#   'cityname': 'Berkeley',
#   'data_value': '10.4',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '37.8725678765',
#                   'longitude': '-122.274907975',
#                   'needs_recoding': False},
#   'high_confidence_limit': '10.6',
#   'low_confidence_limit': '10.2',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '112580',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0606000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0617918',
#   'cityname': 'Daly City',
#   'data_value': '9.4',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '37.6861552276',
#                   'longitude': '-122.468298024',
#                   'needs_recoding': False},
#   'high_confidence_limit': '9.6',
#   'low_confidence_limit': '9.2',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '101123',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0617918',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0611194',
#   'cityname': 'Carlsbad',
#   'data_value': '9.9',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.1248051026',
#                   'longitude': '-117.282903303',
#                   'needs_recoding': False},
#   'high_confidence_limit': '10.2',
#   'low_confidence_limit': '9.6',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '105328',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0611194',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0608786',
#   'cityname': 'Buena Park',
#   'data_value': '11.8',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.8572126844',
#                   'longitude': '-118.004517591',
#                   'needs_recoding': False},
#   'high_confidence_limit': '12.0',
#   'low_confidence_limit': '11.5',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '80530',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0608786',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0611530',
#   'cityname': 'Carson',
#   'data_value': '11.2',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.8374083001',
#                   'longitude': '-118.255936422',
#                   'needs_recoding': False},
#   'high_confidence_limit': '11.5',
#   'low_confidence_limit': '11.0',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '91714',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0611530',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0616350',
#   'cityname': 'Corona',
#   'data_value': '12.9',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.8623571787',
#                   'longitude': '-117.564224471',
#                   'needs_recoding': False},
#   'high_confidence_limit': '13.0',
#   'low_confidence_limit': '12.7',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '152374',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0616350',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0603666',
#   'cityname': 'Baldwin Park',
#   'data_value': '12.6',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '34.082871519',
#                   'longitude': '-117.972100918',
#                   'needs_recoding': False},
#   'high_confidence_limit': '12.9',
#   'low_confidence_limit': '12.3',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '75390',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0603666',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0614218',
#   'cityname': 'Clovis',
#   'data_value': '12.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '36.8289400179',
#                   'longitude': '-119.68665285',
#                   'needs_recoding': False},
#   'high_confidence_limit': '12.8',
#   'low_confidence_limit': '12.3',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '95631',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0614218',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0613014',
#   'cityname': 'Chico',
#   'data_value': '14.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '39.7568503668',
#                   'longitude': '-121.815983972',
#                   'needs_recoding': False},
#   'high_confidence_limit': '14.4',
#   'low_confidence_limit': '13.7',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '86187',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0613014',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0613214',
#   'cityname': 'Chino Hills',
#   'data_value': '9.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.950774546',
#                   'longitude': '-117.725326968',
#                   'needs_recoding': False},
#   'high_confidence_limit': '9.7',
#   'low_confidence_limit': '9.2',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '74799',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0613214',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0615044',
#   'cityname': 'Compton',
#   'data_value': '15.6',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.892965693',
#                   'longitude': '-118.227506568',
#                   'needs_recoding': False},
#   'high_confidence_limit': '15.9',
#   'low_confidence_limit': '15.3',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '96455',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0615044',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0613588',
#   'cityname': 'Citrus Heights',
#   'data_value': '14.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '38.6947788342',
#                   'longitude': '-121.287991502',
#                   'needs_recoding': False},
#   'high_confidence_limit': '14.4',
#   'low_confidence_limit': '13.8',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '83301',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0613588',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0604982',
#   'cityname': 'Bellflower',
#   'data_value': '12.8',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.8880417923',
#                   'longitude': '-118.127100236',
#                   'needs_recoding': False},
#   'high_confidence_limit': '13.0',
#   'low_confidence_limit': '12.6',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '76616',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0604982',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0613210',
#   'cityname': 'Chino',
#   'data_value': '12.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.983588126',
#                   'longitude': '-117.665296584',
#                   'needs_recoding': False},
#   'high_confidence_limit': '12.4',
#   'low_confidence_limit': '11.8',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '77983',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0613210',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0616532',
#   'cityname': 'Costa Mesa',
#   'data_value': '12.2',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.6667651353',
#                   'longitude': '-117.91350475',
#                   'needs_recoding': False},
#   'high_confidence_limit': '12.5',
#   'low_confidence_limit': '12.0',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '109960',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0616532',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0603526',
#   'cityname': 'Bakersfield',
#   'data_value': '14.2',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '35.3513302855',
#                   'longitude': '-119.029786003',
#                   'needs_recoding': False},
#   'high_confidence_limit': '14.3',
#   'low_confidence_limit': '14.0',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '347483',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0603526',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0613392',
#   'cityname': 'Chula Vista',
#   'data_value': '11.7',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '32.6282964262',
#                   'longitude': '-117.010042407',
#                   'needs_recoding': False},
#   'high_confidence_limit': '11.9',
#   'low_confidence_limit': '11.6',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '243916',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0613392',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0602364',
#   'cityname': 'Apple Valley',
#   'data_value': '14.6',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '34.5315984948',
#                   'longitude': '-117.211012664',
#                   'needs_recoding': False},
#   'high_confidence_limit': '14.9',
#   'low_confidence_limit': '14.2',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '69135',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0602364',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0608954',
#   'cityname': 'Burbank',
#   'data_value': '11.3',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '34.1879799605',
#                   'longitude': '-118.323429032',
#                   'needs_recoding': False},
#   'high_confidence_limit': '11.6',
#   'low_confidence_limit': '11.1',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '103340',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0608954',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0616000',
#   'cityname': 'Concord',
#   'data_value': '12.3',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '37.9721810307',
#                   'longitude': '-122.001588036',
#                   'needs_recoding': False},
#   'high_confidence_limit': '12.5',
#   'low_confidence_limit': '12.1',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '122067',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0616000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0629000',
#   'cityname': 'Garden Grove',
#   'data_value': '12.2',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.7786940635',
#                   'longitude': '-117.960111162',
#                   'needs_recoding': False},
#   'high_confidence_limit': '12.4',
#   'low_confidence_limit': '12.0',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '170883',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0629000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0630000',
#   'cityname': 'Glendale',
#   'data_value': '12.3',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '34.181889373',
#                   'longitude': '-118.24676666',
#                   'needs_recoding': False},
#   'high_confidence_limit': '12.5',
#   'low_confidence_limit': '12.1',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '191719',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0630000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0633000',
#   'cityname': 'Hayward',
#   'data_value': '11.7',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '37.6329591551',
#                   'longitude': '-122.077051051',
#                   'needs_recoding': False},
#   'high_confidence_limit': '11.8',
#   'low_confidence_limit': '11.5',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '144186',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0633000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0622804',
#   'cityname': 'Escondido',
#   'data_value': '13.6',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.1346952955',
#                   'longitude': '-117.072122618',
#                   'needs_recoding': False},
#   'high_confidence_limit': '13.8',
#   'low_confidence_limit': '13.4',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '143911',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0622804',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0619766',
#   'cityname': 'Downey',
#   'data_value': '11.8',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.937867256',
#                   'longitude': '-118.131150116',
#                   'needs_recoding': False},
#   'high_confidence_limit': '12.1',
#   'low_confidence_limit': '11.6',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '111772',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0619766',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0622020',
#   'cityname': 'Elk Grove',
#   'data_value': '11.4',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '38.4159992006',
#                   'longitude': '-121.384137762',
#                   'needs_recoding': False},
#   'high_confidence_limit': '11.5',
#   'low_confidence_limit': '11.2',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '153015',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0622020',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0624638',
#   'cityname': 'Folsom',
#   'data_value': '10.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '38.6750494328',
#                   'longitude': '-121.147605753',
#                   'needs_recoding': False},
#   'high_confidence_limit': '10.8',
#   'low_confidence_limit': '10.2',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '72203',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0624638',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0621712',
#   'cityname': 'El Cajon',
#   'data_value': '15.0',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '32.8016581921',
#                   'longitude': '-116.960483614',
#                   'needs_recoding': False},
#   'high_confidence_limit': '15.3',
#   'low_confidence_limit': '14.8',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '99478',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0621712',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0623182',
#   'cityname': 'Fairfield',
#   'data_value': '12.7',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '38.2558446343',
#                   'longitude': '-122.039303253',
#                   'needs_recoding': False},
#   'high_confidence_limit': '12.9',
#   'low_confidence_limit': '12.5',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '105321',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0623182',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0622230',
#   'cityname': 'El Monte',
#   'data_value': '13.9',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '34.073919653',
#                   'longitude': '-118.029071951',
#                   'needs_recoding': False},
#   'high_confidence_limit': '14.1',
#   'low_confidence_limit': '13.6',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '113475',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0622230',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '0624680',
# ...
#   'low_confidence_limit': '14.7',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '73917',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5335275',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '5182000',
#   'cityname': 'Virginia Beach',
#   'data_value': '11.7',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '36.7534593339',
#                   'longitude': '-76.0589579522',
#                   'needs_recoding': False},
#   'high_confidence_limit': '11.8',
#   'low_confidence_limit': '11.6',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '437994',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'VA',
#   'statedesc': 'Virginia',
#   'uniqueid': '5182000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '5167000',
#   'cityname': 'Richmond',
#   'data_value': '14.3',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '37.5293933083',
#                   'longitude': '-77.475568168',
#                   'needs_recoding': False},
#   'high_confidence_limit': '14.5',
#   'low_confidence_limit': '14.1',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '204214',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'VA',
#   'statedesc': 'Virginia',
#   'uniqueid': '5167000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '5335415',
#   'cityname': 'Kent',
#   'data_value': '14.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '47.3849636272',
#                   'longitude': '-122.217890194',
#                   'needs_recoding': False},
#   'high_confidence_limit': '14.8',
#   'low_confidence_limit': '14.3',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '92411',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5335415',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '5414600',
#   'cityname': 'Charleston',
#   'data_value': '16.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '38.3484079736',
#                   'longitude': '-81.632165003',
#                   'needs_recoding': False},
#   'high_confidence_limit': '16.9',
#   'low_confidence_limit': '16.1',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '51400',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'WV',
#   'statedesc': 'West Virginia',
#   'uniqueid': '5414600',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '5502375',
#   'cityname': 'Appleton',
#   'data_value': '12.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '44.2776987457',
#                   'longitude': '-88.3897664444',
#                   'needs_recoding': False},
#   'high_confidence_limit': '12.4',
#   'low_confidence_limit': '11.8',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '72623',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'WI',
#   'statedesc': 'Wisconsin',
#   'uniqueid': '5502375',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '5548000',
#   'cityname': 'Madison',
#   'data_value': '10.8',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '43.0809865694',
#                   'longitude': '-89.3915106344',
#                   'needs_recoding': False},
#   'high_confidence_limit': '11.0',
#   'low_confidence_limit': '10.6',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '233209',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'WI',
#   'statedesc': 'Wisconsin',
#   'uniqueid': '5548000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '5380010',
#   'cityname': 'Yakima',
#   'data_value': '16.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '46.5925792092',
#                   'longitude': '-120.547807614',
#                   'needs_recoding': False},
#   'high_confidence_limit': '16.5',
#   'low_confidence_limit': '15.8',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '91067',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5380010',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '5553000',
#   'cityname': 'Milwaukee',
#   'data_value': '15.3',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '43.0641258925',
#                   'longitude': '-87.9672412429',
#                   'needs_recoding': False},
#   'high_confidence_limit': '15.4',
#   'low_confidence_limit': '15.2',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '594833',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'WI',
#   'statedesc': 'Wisconsin',
#   'uniqueid': '5553000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '5539225',
#   'cityname': 'Kenosha',
#   'data_value': '13.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '42.585570271',
#                   'longitude': '-87.8735745085',
#                   'needs_recoding': False},
#   'high_confidence_limit': '13.4',
#   'low_confidence_limit': '12.8',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '99218',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'WI',
#   'statedesc': 'Wisconsin',
#   'uniqueid': '5539225',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '5374060',
#   'cityname': 'Vancouver',
#   'data_value': '14.0',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '45.6357172365',
#                   'longitude': '-122.598539476',
#                   'needs_recoding': False},
#   'high_confidence_limit': '14.3',
#   'low_confidence_limit': '13.8',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '161791',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5374060',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '5367000',
#   'cityname': 'Spokane',
#   'data_value': '15.2',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '47.6736243259',
#                   'longitude': '-117.415973291',
#                   'needs_recoding': False},
#   'high_confidence_limit': '15.4',
#   'low_confidence_limit': '15.0',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '208916',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5367000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '5367167',
#   'cityname': 'Spokane Valley',
#   'data_value': '14.6',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '47.662556574',
#                   'longitude': '-117.234571922',
#                   'needs_recoding': False},
#   'high_confidence_limit': '14.9',
#   'low_confidence_limit': '14.3',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '89755',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5367167',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '5370000',
#   'cityname': 'Tacoma',
#   'data_value': '14.8',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '47.2425411445',
#                   'longitude': '-122.45447391',
#                   'needs_recoding': False},
#   'high_confidence_limit': '15.0',
#   'low_confidence_limit': '14.6',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '198397',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5370000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '5531000',
#   'cityname': 'Green Bay',
#   'data_value': '13.3',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '44.5149847816',
#                   'longitude': '-87.9896195955',
#                   'needs_recoding': False},
#   'high_confidence_limit': '13.6',
#   'low_confidence_limit': '13.0',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '104057',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'WI',
#   'statedesc': 'Wisconsin',
#   'uniqueid': '5531000',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '5584250',
#   'cityname': 'Waukesha',
#   'data_value': '11.7',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '43.0093332215',
#                   'longitude': '-88.2457679157',
#                   'needs_recoding': False},
#   'high_confidence_limit': '12.0',
#   'low_confidence_limit': '11.3',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '70718',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'WI',
#   'statedesc': 'Wisconsin',
#   'uniqueid': '5584250',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '5613900',
#   'cityname': 'Cheyenne',
#   'data_value': '11.6',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '41.1460804265',
#                   'longitude': '-104.789064332',
#                   'needs_recoding': False},
#   'high_confidence_limit': '11.9',
#   'low_confidence_limit': '11.2',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '59466',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'WY',
#   'statedesc': 'Wyoming',
#   'uniqueid': '5613900',
#   'year': '2017'},
#  {'category': 'Health Outcomes',
#   'categoryid': 'HLTHOUT',
#   'cityfips': '5566000',
#   'cityname': 'Racine',
#   'data_value': '13.9',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '42.7274599494',
#                   'longitude': '-87.813453024',
#                   'needs_recoding': False},
#   'high_confidence_limit': '14.2',
#   'low_confidence_limit': '13.6',
#   'measure': 'Mental health not good for >=14 days among adults aged >=18 '
#              'Years',
#   'measureid': 'MHLTH',
#   'populationcount': '78860',
#   'short_question_text': 'Mental Health',
#   'stateabbr': 'WI',
#   'statedesc': 'Wisconsin',
#   'uniqueid': '5566000',
#   'year': '2017'}]

# %%
# Create the dataframe
mental_df = pd.DataFrame()
mental_df['City Name'] = ""
mental_df['State'] = ""
mental_df['Lat'] = ""
mental_df['Lon'] = ""
mental_df['% Depress'] = ""

mental_df
# Out:
# Empty DataFrame
# Columns: [City Name, State, Lat, Lon, % Depress]
# Index: []

# %%
# Add values to dataframe

for x in range(len(mental_data)):
    mental_df.loc[x,'City Name'] = mental_data[x]['cityname']
    mental_df.loc[x,'Lat'] = mental_data[x]['geolocation']['latitude']
    mental_df.loc[x,'Lon'] = mental_data[x]['geolocation']['longitude']
    mental_df.loc[x, '% Depress'] = mental_data[x]['data_value']
    mental_df.loc[x, 'State'] = mental_data[x]['stateabbr']

mental_df.head()
# Out:
#     City Name State            Lat             Lon % Depress
# 0      Mobile    AL  30.6776248648  -88.1184482714      16.3
# 1     Gilbert    AZ   33.310149392  -111.746237467      10.9
# 2    Avondale    AZ  33.3858367405  -112.323626619      13.5
# 3  Montgomery    AL  32.3472645333  -86.2677059552      15.8
# 4   Anchorage    AK   61.149868731  -149.111113424      11.0

# %% [markdown]
# ## Alice: Depression vs Binge Drinking

# %%
# Import binge drinking data
drinking_base_url = "https://data.cdc.gov/resource/gqat-rcqz.json?"
params = {
    "GeographicLevel" : "City",
    "DataValueTypeID" : "AgeAdjPrv"
}
drinking_data = requests.get(drinking_base_url, params = params).json()
pprint(drinking_data)
# Out:
# [{'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0636448',
#   'cityname': 'Indio',
#   'data_value': '17.7',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.7298067837',
#                   'longitude': '-116.237258141',
#                   'needs_recoding': False},
#   'high_confidence_limit': '17.9',
#   'low_confidence_limit': '17.5',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '76036',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0636448',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0628000',
#   'cityname': 'Fullerton',
#   'data_value': '18.4',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.8840378013',
#                   'longitude': '-117.927850895',
#                   'needs_recoding': False},
#   'high_confidence_limit': '18.5',
#   'low_confidence_limit': '18.3',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '135161',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0628000',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '1269700',
#   'cityname': 'Sunrise',
#   'data_value': '16.6',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '26.1546878303',
#                   'longitude': '-80.299841102',
#                   'needs_recoding': False},
#   'high_confidence_limit': '16.7',
#   'low_confidence_limit': '16.4',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '84439',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'FL',
#   'statedesc': 'Florida',
#   'uniqueid': '1269700',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0680238',
#   'cityname': 'Tracy',
#   'data_value': '20.0',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '37.7243277375',
#                   'longitude': '-121.444621463',
#                   'needs_recoding': False},
#   'high_confidence_limit': '20.2',
#   'low_confidence_limit': '19.8',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '82922',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0680238',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '2148006',
#   'cityname': 'Louisville',
#   'data_value': '18.6',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '38.1777689918',
#                   'longitude': '-85.6664099974',
#                   'needs_recoding': False},
#   'high_confidence_limit': '18.7',
#   'low_confidence_limit': '18.6',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '597337',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'KY',
#   'statedesc': 'Kentucky',
#   'uniqueid': '2148006',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '3006550',
#   'cityname': 'Billings',
#   'data_value': '23.0',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '45.7893102609',
#                   'longitude': '-108.54882784',
#                   'needs_recoding': False},
#   'high_confidence_limit': '23.1',
#   'low_confidence_limit': '22.8',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '104170',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'MT',
#   'statedesc': 'Montana',
#   'uniqueid': '3006550',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '4837000',
#   'cityname': 'Irving',
#   'data_value': '16.6',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '32.8583808131',
#                   'longitude': '-96.9703058323',
#                   'needs_recoding': False},
#   'high_confidence_limit': '16.7',
#   'low_confidence_limit': '16.5',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '216290',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'TX',
#   'statedesc': 'Texas',
#   'uniqueid': '4837000',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '4801000',
#   'cityname': 'Abilene',
#   'data_value': '18.8',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '32.4546510898',
#                   'longitude': '-99.7383043723',
#                   'needs_recoding': False},
#   'high_confidence_limit': '18.9',
#   'low_confidence_limit': '18.6',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '117063',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'TX',
#   'statedesc': 'Texas',
#   'uniqueid': '4801000',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '4806128',
#   'cityname': 'Baytown',
#   'data_value': '19.0',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '29.7571153043',
#                   'longitude': '-94.9676276217',
#                   'needs_recoding': False},
#   'high_confidence_limit': '19.1',
#   'low_confidence_limit': '18.8',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '71802',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'TX',
#   'statedesc': 'Texas',
#   'uniqueid': '4806128',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '4879000',
#   'cityname': 'Wichita Falls',
#   'data_value': '17.2',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.9072739838',
#                   'longitude': '-98.5292981697',
#                   'needs_recoding': False},
#   'high_confidence_limit': '17.4',
#   'low_confidence_limit': '17.0',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '104553',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'TX',
#   'statedesc': 'Texas',
#   'uniqueid': '4879000',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5303180',
#   'cityname': 'Auburn',
#   'data_value': '17.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '47.3038544325',
#                   'longitude': '-122.210810557',
#                   'needs_recoding': False},
#   'high_confidence_limit': '17.2',
#   'low_confidence_limit': '17.0',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '70180',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5303180',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0177256',
#   'cityname': 'Tuscaloosa',
#   'data_value': '13.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.2336083951',
#                   'longitude': '-87.5268004073',
#                   'needs_recoding': False},
#   'high_confidence_limit': '13.2',
#   'low_confidence_limit': '13.0',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '90468',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'AL',
#   'statedesc': 'Alabama',
#   'uniqueid': '0177256',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0150000',
#   'cityname': 'Mobile',
#   'data_value': '13.9',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '30.6776248648',
#                   'longitude': '-88.1184482714',
#                   'needs_recoding': False},
#   'high_confidence_limit': '14.0',
#   'low_confidence_limit': '13.8',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '195111',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'AL',
#   'statedesc': 'Alabama',
#   'uniqueid': '0150000',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0412000',
#   'cityname': 'Chandler',
#   'data_value': '17.9',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.28318981',
#                   'longitude': '-111.852210033',
#                   'needs_recoding': False},
#   'high_confidence_limit': '18.0',
#   'low_confidence_limit': '17.9',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '236123',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0412000',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0107000',
#   'cityname': 'Birmingham',
#   'data_value': '11.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.5275663773',
#                   'longitude': '-86.7988174678',
#                   'needs_recoding': False},
#   'high_confidence_limit': '11.5',
#   'low_confidence_limit': '11.4',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '212237',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'AL',
#   'statedesc': 'Alabama',
#   'uniqueid': '0107000',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0473000',
#   'cityname': 'Tempe',
#   'data_value': '17.2',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.3882640307',
#                   'longitude': '-111.931802302',
#                   'needs_recoding': False},
#   'high_confidence_limit': '17.3',
#   'low_confidence_limit': '17.1',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '161719',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0473000',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0427400',
#   'cityname': 'Gilbert',
#   'data_value': '19.0',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.310149392',
#                   'longitude': '-111.746237467',
#                   'needs_recoding': False},
#   'high_confidence_limit': '19.1',
#   'low_confidence_limit': '18.9',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '208453',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0427400',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0404720',
#   'cityname': 'Avondale',
#   'data_value': '16.2',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.3858367405',
#                   'longitude': '-112.323626619',
#                   'needs_recoding': False},
#   'high_confidence_limit': '16.3',
#   'low_confidence_limit': '16.1',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '76238',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0404720',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '4841464',
#   'cityname': 'Laredo',
#   'data_value': '15.0',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '27.5482572475',
#                   'longitude': '-99.4867797312',
#                   'needs_recoding': False},
#   'high_confidence_limit': '15.2',
#   'low_confidence_limit': '14.9',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '236091',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'TX',
#   'statedesc': 'Texas',
#   'uniqueid': '4841464',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '4845384',
#   'cityname': 'McAllen',
#   'data_value': '15.7',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '26.2186289942',
#                   'longitude': '-98.2451704536',
#                   'needs_recoding': False},
#   'high_confidence_limit': '15.9',
#   'low_confidence_limit': '15.5',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '129877',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'TX',
#   'statedesc': 'Texas',
#   'uniqueid': '4845384',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '4848072',
#   'cityname': 'Midland',
#   'data_value': '19.6',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '32.0285948356',
#                   'longitude': '-102.109700973',
#                   'needs_recoding': False},
#   'high_confidence_limit': '19.7',
#   'low_confidence_limit': '19.5',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '111147',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'TX',
#   'statedesc': 'Texas',
#   'uniqueid': '4848072',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0454050',
#   'cityname': 'Peoria',
#   'data_value': '18.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.7847206422',
#                   'longitude': '-112.298680584',
#                   'needs_recoding': False},
#   'high_confidence_limit': '18.6',
#   'low_confidence_limit': '18.4',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '154065',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0454050',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0471510',
#   'cityname': 'Surprise',
#   'data_value': '18.2',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.6803835177',
#                   'longitude': '-112.452218439',
#                   'needs_recoding': False},
#   'high_confidence_limit': '18.4',
#   'low_confidence_limit': '18.1',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '117517',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0471510',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0600884',
#   'cityname': 'Alhambra',
#   'data_value': '13.8',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '34.0839734383',
#                   'longitude': '-118.135514119',
#                   'needs_recoding': False},
#   'high_confidence_limit': '13.9',
#   'low_confidence_limit': '13.7',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '83089',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0600884',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0535710',
#   'cityname': 'Jonesboro',
#   'data_value': '14.8',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '35.8208121538',
#                   'longitude': '-90.6794991686',
#                   'needs_recoding': False},
#   'high_confidence_limit': '15.0',
#   'low_confidence_limit': '14.6',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '67263',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'AR',
#   'statedesc': 'Arkansas',
#   'uniqueid': '0535710',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0541000',
#   'cityname': 'Little Rock',
#   'data_value': '15.2',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '34.7253957894',
#                   'longitude': '-92.3583751863',
#                   'needs_recoding': False},
#   'high_confidence_limit': '15.2',
#   'low_confidence_limit': '15.1',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '193524',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'AR',
#   'statedesc': 'Arkansas',
#   'uniqueid': '0541000',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0602252',
#   'cityname': 'Antioch',
#   'data_value': '17.9',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '37.9777042922',
#                   'longitude': '-121.796606971',
#                   'needs_recoding': False},
#   'high_confidence_limit': '18.0',
#   'low_confidence_limit': '17.8',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '102372',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0602252',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0523290',
#   'cityname': 'Fayetteville',
#   'data_value': '16.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '36.0712117312',
#                   'longitude': '-94.1659600436',
#                   'needs_recoding': False},
#   'high_confidence_limit': '16.3',
#   'low_confidence_limit': '15.9',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '73580',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'AR',
#   'statedesc': 'Arkansas',
#   'uniqueid': '0523290',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0566080',
#   'cityname': 'Springdale',
#   'data_value': '15.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '36.1869932598',
#                   'longitude': '-94.1536274531',
#                   'needs_recoding': False},
#   'high_confidence_limit': '15.3',
#   'low_confidence_limit': '14.9',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '69797',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'AR',
#   'statedesc': 'Arkansas',
#   'uniqueid': '0566080',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0477000',
#   'cityname': 'Tucson',
#   'data_value': '15.3',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '32.1567244483',
#                   'longitude': '-110.877085494',
#                   'needs_recoding': False},
#   'high_confidence_limit': '15.3',
#   'low_confidence_limit': '15.2',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '520116',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0477000',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0485540',
#   'cityname': 'Yuma',
#   'data_value': '17.6',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '32.5986027117',
#                   'longitude': '-114.54836837',
#                   'needs_recoding': False},
#   'high_confidence_limit': '17.7',
#   'low_confidence_limit': '17.5',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '93064',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0485540',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0465000',
#   'cityname': 'Scottsdale',
#   'data_value': '19.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.6872493651',
#                   'longitude': '-111.865085877',
#                   'needs_recoding': False},
#   'high_confidence_limit': '19.2',
#   'low_confidence_limit': '19.1',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '217385',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0465000',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0600562',
#   'cityname': 'Alameda',
#   'data_value': '19.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '37.7650849031',
#                   'longitude': '-122.266489842',
#                   'needs_recoding': False},
#   'high_confidence_limit': '19.2',
#   'low_confidence_limit': '19.0',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '73812',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0600562',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0524550',
#   'cityname': 'Fort Smith',
#   'data_value': '14.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '35.3491692636',
#                   'longitude': '-94.3696317306',
#                   'needs_recoding': False},
#   'high_confidence_limit': '14.3',
#   'low_confidence_limit': '14.0',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '86209',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'AR',
#   'statedesc': 'Arkansas',
#   'uniqueid': '0524550',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0602000',
#   'cityname': 'Anaheim',
#   'data_value': '18.3',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.8389076996',
#                   'longitude': '-117.857613481',
#                   'needs_recoding': False},
#   'high_confidence_limit': '18.4',
#   'low_confidence_limit': '18.2',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '336265',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0602000',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0613210',
#   'cityname': 'Chino',
#   'data_value': '18.3',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.983588126',
#                   'longitude': '-117.665296584',
#                   'needs_recoding': False},
#   'high_confidence_limit': '18.5',
#   'low_confidence_limit': '18.1',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '77983',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0613210',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0633000',
#   'cityname': 'Hayward',
#   'data_value': '18.3',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '37.6329591551',
#                   'longitude': '-122.077051051',
#                   'needs_recoding': False},
#   'high_confidence_limit': '18.4',
#   'low_confidence_limit': '18.2',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '144186',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0633000',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0617918',
#   'cityname': 'Daly City',
#   'data_value': '14.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '37.6861552276',
#                   'longitude': '-122.468298024',
#                   'needs_recoding': False},
#   'high_confidence_limit': '14.2',
#   'low_confidence_limit': '14.0',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '101123',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0617918',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0616532',
#   'cityname': 'Costa Mesa',
#   'data_value': '20.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.6667651353',
#                   'longitude': '-117.91350475',
#                   'needs_recoding': False},
#   'high_confidence_limit': '20.6',
#   'low_confidence_limit': '20.3',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '109960',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0616532',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0615044',
#   'cityname': 'Compton',
#   'data_value': '15.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.892965693',
#                   'longitude': '-118.227506568',
#                   'needs_recoding': False},
#   'high_confidence_limit': '15.6',
#   'low_confidence_limit': '15.3',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '96455',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0615044',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0616000',
#   'cityname': 'Concord',
#   'data_value': '19.2',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '37.9721810307',
#                   'longitude': '-122.001588036',
#                   'needs_recoding': False},
#   'high_confidence_limit': '19.3',
#   'low_confidence_limit': '19.1',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '122067',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0616000',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0604982',
#   'cityname': 'Bellflower',
#   'data_value': '17.2',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.8880417923',
#                   'longitude': '-118.127100236',
#                   'needs_recoding': False},
#   'high_confidence_limit': '17.3',
#   'low_confidence_limit': '17.1',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '76616',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0604982',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0613392',
#   'cityname': 'Chula Vista',
#   'data_value': '18.3',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '32.6282964262',
#                   'longitude': '-117.010042407',
#                   'needs_recoding': False},
#   'high_confidence_limit': '18.3',
#   'low_confidence_limit': '18.2',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '243916',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0613392',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0611530',
#   'cityname': 'Carson',
#   'data_value': '16.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.8374083001',
#                   'longitude': '-118.255936422',
#                   'needs_recoding': False},
#   'high_confidence_limit': '16.2',
#   'low_confidence_limit': '16.0',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '91714',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0611530',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0606000',
#   'cityname': 'Berkeley',
#   'data_value': '19.8',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '37.8725678765',
#                   'longitude': '-122.274907975',
#                   'needs_recoding': False},
#   'high_confidence_limit': '19.9',
#   'low_confidence_limit': '19.7',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '112580',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0606000',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0614218',
#   'cityname': 'Clovis',
#   'data_value': '18.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '36.8289400179',
#                   'longitude': '-119.68665285',
#                   'needs_recoding': False},
#   'high_confidence_limit': '18.3',
#   'low_confidence_limit': '18.0',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '95631',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0614218',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0603526',
#   'cityname': 'Bakersfield',
#   'data_value': '16.9',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '35.3513302855',
#                   'longitude': '-119.029786003',
#                   'needs_recoding': False},
#   'high_confidence_limit': '17.0',
#   'low_confidence_limit': '16.8',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '347483',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0603526',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0135896',
#   'cityname': 'Hoover',
#   'data_value': '15.7',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.3767602729',
#                   'longitude': '-86.8051937568',
#                   'needs_recoding': False},
#   'high_confidence_limit': '15.8',
#   'low_confidence_limit': '15.5',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '81619',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'AL',
#   'statedesc': 'Alabama',
#   'uniqueid': '0135896',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0608954',
#   'cityname': 'Burbank',
#   'data_value': '19.8',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '34.1879799605',
#                   'longitude': '-118.323429032',
#                   'needs_recoding': False},
#   'high_confidence_limit': '19.9',
#   'low_confidence_limit': '19.7',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '103340',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0608954',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0611194',
#   'cityname': 'Carlsbad',
#   'data_value': '22.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.1248051026',
#                   'longitude': '-117.282903303',
#                   'needs_recoding': False},
#   'high_confidence_limit': '22.6',
#   'low_confidence_limit': '22.3',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '105328',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0611194',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0602364',
#   'cityname': 'Apple Valley',
#   'data_value': '18.4',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '34.5315984948',
#                   'longitude': '-117.211012664',
#                   'needs_recoding': False},
#   'high_confidence_limit': '18.6',
#   'low_confidence_limit': '18.2',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '69135',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0602364',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0608786',
#   'cityname': 'Buena Park',
#   'data_value': '17.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.8572126844',
#                   'longitude': '-118.004517591',
#                   'needs_recoding': False},
#   'high_confidence_limit': '17.6',
#   'low_confidence_limit': '17.3',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '80530',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0608786',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0613588',
#   'cityname': 'Citrus Heights',
#   'data_value': '20.7',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '38.6947788342',
#                   'longitude': '-121.287991502',
#                   'needs_recoding': False},
#   'high_confidence_limit': '20.8',
#   'low_confidence_limit': '20.5',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '83301',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0613588',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0616350',
#   'cityname': 'Corona',
#   'data_value': '18.9',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.8623571787',
#                   'longitude': '-117.564224471',
#                   'needs_recoding': False},
#   'high_confidence_limit': '19.0',
#   'low_confidence_limit': '18.8',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '152374',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0616350',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0613014',
#   'cityname': 'Chico',
# ...
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5305210',
#   'cityname': 'Bellevue',
#   'data_value': '16.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '47.5962437606',
#                   'longitude': '-122.153569982',
#                   'needs_recoding': False},
#   'high_confidence_limit': '16.6',
#   'low_confidence_limit': '16.4',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '122363',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5305210',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5323515',
#   'cityname': 'Federal Way',
#   'data_value': '16.2',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '47.3090846316',
#                   'longitude': '-122.335755583',
#                   'needs_recoding': False},
#   'high_confidence_limit': '16.3',
#   'low_confidence_limit': '16.1',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '89306',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5323515',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5335275',
#   'cityname': 'Kennewick',
#   'data_value': '16.7',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '46.198438428',
#                   'longitude': '-119.173245847',
#                   'needs_recoding': False},
#   'high_confidence_limit': '16.9',
#   'low_confidence_limit': '16.5',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '73917',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5335275',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5335415',
#   'cityname': 'Kent',
#   'data_value': '15.7',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '47.3849636272',
#                   'longitude': '-122.217890194',
#                   'needs_recoding': False},
#   'high_confidence_limit': '15.8',
#   'low_confidence_limit': '15.6',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '92411',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5335415',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5305280',
#   'cityname': 'Bellingham',
#   'data_value': '19.3',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '48.7535370315',
#                   'longitude': '-122.468092906',
#                   'needs_recoding': False},
#   'high_confidence_limit': '19.5',
#   'low_confidence_limit': '19.1',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '80885',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5305280',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5553000',
#   'cityname': 'Milwaukee',
#   'data_value': '21.4',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '43.0641258925',
#                   'longitude': '-87.9672412429',
#                   'needs_recoding': False},
#   'high_confidence_limit': '21.5',
#   'low_confidence_limit': '21.3',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '594833',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'WI',
#   'statedesc': 'Wisconsin',
#   'uniqueid': '5553000',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5548000',
#   'cityname': 'Madison',
#   'data_value': '25.4',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '43.0809865694',
#                   'longitude': '-89.3915106344',
#                   'needs_recoding': False},
#   'high_confidence_limit': '25.5',
#   'low_confidence_limit': '25.3',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '233209',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'WI',
#   'statedesc': 'Wisconsin',
#   'uniqueid': '5548000',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5370000',
#   'cityname': 'Tacoma',
#   'data_value': '16.4',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '47.2425411445',
#                   'longitude': '-122.45447391',
#                   'needs_recoding': False},
#   'high_confidence_limit': '16.5',
#   'low_confidence_limit': '16.4',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '198397',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5370000',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5380010',
#   'cityname': 'Yakima',
#   'data_value': '14.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '46.5925792092',
#                   'longitude': '-120.547807614',
#                   'needs_recoding': False},
#   'high_confidence_limit': '14.7',
#   'low_confidence_limit': '14.4',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '91067',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5380010',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5502375',
#   'cityname': 'Appleton',
#   'data_value': '25.4',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '44.2776987457',
#                   'longitude': '-88.3897664444',
#                   'needs_recoding': False},
#   'high_confidence_limit': '25.6',
#   'low_confidence_limit': '25.2',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '72623',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'WI',
#   'statedesc': 'Wisconsin',
#   'uniqueid': '5502375',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5414600',
#   'cityname': 'Charleston',
#   'data_value': '12.9',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '38.3484079736',
#                   'longitude': '-81.632165003',
#                   'needs_recoding': False},
#   'high_confidence_limit': '13.0',
#   'low_confidence_limit': '12.7',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '51400',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'WV',
#   'statedesc': 'West Virginia',
#   'uniqueid': '5414600',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5539225',
#   'cityname': 'Kenosha',
#   'data_value': '24.4',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '42.585570271',
#                   'longitude': '-87.8735745085',
#                   'needs_recoding': False},
#   'high_confidence_limit': '24.6',
#   'low_confidence_limit': '24.2',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '99218',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'WI',
#   'statedesc': 'Wisconsin',
#   'uniqueid': '5539225',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5531000',
#   'cityname': 'Green Bay',
#   'data_value': '25.0',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '44.5149847816',
#                   'longitude': '-87.9896195955',
#                   'needs_recoding': False},
#   'high_confidence_limit': '25.1',
#   'low_confidence_limit': '24.8',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '104057',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'WI',
#   'statedesc': 'Wisconsin',
#   'uniqueid': '5531000',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5374060',
#   'cityname': 'Vancouver',
#   'data_value': '17.0',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '45.6357172365',
#                   'longitude': '-122.598539476',
#                   'needs_recoding': False},
#   'high_confidence_limit': '17.1',
#   'low_confidence_limit': '16.9',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '161791',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5374060',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5367167',
#   'cityname': 'Spokane Valley',
#   'data_value': '17.2',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '47.662556574',
#                   'longitude': '-117.234571922',
#                   'needs_recoding': False},
#   'high_confidence_limit': '17.3',
#   'low_confidence_limit': '17.0',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '89755',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5367167',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5584250',
#   'cityname': 'Waukesha',
#   'data_value': '23.7',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '43.0093332215',
#                   'longitude': '-88.2457679157',
#                   'needs_recoding': False},
#   'high_confidence_limit': '23.9',
#   'low_confidence_limit': '23.5',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '70718',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'WI',
#   'statedesc': 'Wisconsin',
#   'uniqueid': '5584250',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5613900',
#   'cityname': 'Cheyenne',
#   'data_value': '17.4',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '41.1460804265',
#                   'longitude': '-104.789064332',
#                   'needs_recoding': False},
#   'high_confidence_limit': '17.5',
#   'low_confidence_limit': '17.2',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '59466',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'WY',
#   'statedesc': 'Wyoming',
#   'uniqueid': '5613900',
#   'year': '2017'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5566000',
#   'cityname': 'Racine',
#   'data_value': '23.0',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '42.7274599494',
#                   'longitude': '-87.813453024',
#                   'needs_recoding': False},
#   'high_confidence_limit': '23.2',
#   'low_confidence_limit': '22.9',
#   'measure': 'Binge drinking among adults aged >=18 Years',
#   'measureid': 'BINGE',
#   'populationcount': '78860',
#   'short_question_text': 'Binge Drinking',
#   'stateabbr': 'WI',
#   'statedesc': 'Wisconsin',
#   'uniqueid': '5566000',
#   'year': '2017'}]

# %%
# Create the dataframe
drinking_df = pd.DataFrame()
drinking_df['City Name'] = ""
drinking_df['% Binge Drinking'] = ""

# %%
for x in range(len(drinking_data)):
    drinking_df.loc[x,'City Name'] = drinking_data[x]['cityname']
    drinking_df.loc[x, '% Binge Drinking'] = drinking_data[x]['data_value']

drinking_df.head()
# Out:
#     City Name % Binge Drinking
# 0       Indio             17.7
# 1   Fullerton             18.4
# 2     Sunrise             16.6
# 3       Tracy             20.0
# 4  Louisville             18.6

# %%
# Merge 2 datasets together
depress_drinking_df = pd.merge(mental_df, drinking_df, on='City Name')
depress_drinking_df.head(10)
# Out:
#     City Name State            Lat             Lon % Depress % Binge Drinking
# 0      Mobile    AL  30.6776248648  -88.1184482714      16.3             13.9
# 1     Gilbert    AZ   33.310149392  -111.746237467      10.9             19.0
# 2    Avondale    AZ  33.3858367405  -112.323626619      13.5             16.2
# 3  Montgomery    AL  32.3472645333  -86.2677059552      15.8             13.0
# 4   Anchorage    AK   61.149868731  -149.111113424      11.0             19.0
# 5     Phoenix    AZ  33.5724138695  -112.088995222      13.9             16.3
# 6        Mesa    AZ  33.4022837359  -111.718721181      13.5             17.4
# 7      Peoria    AZ  33.7847206422  -112.298680584      12.2             18.5
# 8      Peoria    AZ  33.7847206422  -112.298680584      12.2             18.4
# 9      Peoria    IL  40.7515684146   -89.615255458      13.9             18.5

# %%
# Converting number columns to numbers
depress_drinking_df['% Depress'] = depress_drinking_df['% Depress'].astype("float")
depress_drinking_df['% Binge Drinking'] = depress_drinking_df['% Binge Drinking'].astype("float")
depress_drinking_df['Lat'] = depress_drinking_df['Lat'].astype("float")
depress_drinking_df['Lon'] = depress_drinking_df['Lon'].astype("float")
depress_drinking_df.dtypes
# Out:
# City Name            object
# State                object
# Lat                 float64
# Lon                 float64
# % Depress           float64
# % Binge Drinking    float64
# dtype: object

# %%
# Mapping depression rate
map_plot_1 = depress_drinking_df.hvplot.points(
    "Lon",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    color = "% Depress",
    size = "% Depress",
    colormap = "coolwarm"
)
hvplot.save(map_plot_1, "Output/DepressMap.png")
map_plot_1
# Out:
# d:\New folder\envs\dev\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: figure(id='p1018', ...)
# WARNING:bokeh.io.export:There were browser warnings and/or errors that may have affected your export
# WARNING:bokeh.io.export:file:///C:/Users/Alice%20Nguyen/Desktop/BootCamp/Project1/Group2/bokehrxibb53f.html - [.WebGL-00002FE80027A300]GL Driver Message (OpenGL, Performance, GL_CLOSE_PATH_NV, High): GPU stall due to ReadPixels
# WARNING:bokeh.io.export:file:///C:/Users/Alice%20Nguyen/Desktop/BootCamp/Project1/Group2/bokehrxibb53f.html - [.WebGL-00002FE80027A300]GL Driver Message (OpenGL, Performance, GL_CLOSE_PATH_NV, High): GPU stall due to ReadPixels
# WARNING:bokeh.io.export:file:///C:/Users/Alice%20Nguyen/Desktop/BootCamp/Project1/Group2/bokehrxibb53f.html - [.WebGL-00002FE80027A300]GL Driver Message (OpenGL, Performance, GL_CLOSE_PATH_NV, High): GPU stall due to ReadPixels
# WARNING:bokeh.io.export:file:///C:/Users/Alice%20Nguyen/Desktop/BootCamp/Project1/Group2/bokehrxibb53f.html - [.WebGL-00002FE80027A300]GL Driver Message (OpenGL, Performance, GL_CLOSE_PATH_NV, High): GPU stall due to ReadPixels (this message will no longer repeat)
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lon,Lat]   (% Depress)

# %% [markdown]
# ### Comment:
# Cities with the high depression polulation are mostly on the east coast, some in the midwest and the west coast cities near the Pacific ocean. Happier cities are mainly in the middle of the map.

# %%
map_plot_2 = depress_drinking_df.hvplot.points(
    "Lon",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    color = "% Binge Drinking",
    colormap = "coolwarm"
)
hvplot.save(map_plot_2, 'Output/DrinkingMap.png')
map_plot_2
# Out:
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: figure(id='p1397', ...)
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lon,Lat]   (% Binge Drinking)

# %% [markdown]
# ### Comment:
# Cities that have the highest binge drinking population are in the midwest, west coast and cities that near the Atlantic ocean.

# %%
# Plot scatter plot
x_values = depress_drinking_df['% Depress']
y_values = depress_drinking_df['% Binge Drinking']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
depress_drinking_df.plot(kind='scatter', x='% Depress', y='% Binge Drinking', title="% of depression population vs % of population that binge drinking")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(14,7),fontsize=15,color="red")
plt.savefig("Output/depressionVsDrinking.jpg")
plt.show()
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: -0.3683445074767244

# %% [markdown]
# ### Comment:
# The correlation between depress population and binge drinking is -0.37. This is a weak correlation.

# %% [markdown]
# ## Kent: Depression vs Sleeping behavior

# %%
# Add sleeping data
sleeping_base_url = "https://data.cdc.gov/resource/eqbn-8mpz.json?"
params = {
    "GeographicLevel" : "City",
    "DataValueTypeID" : "AgeAdjPrv"
}
sleeping_data = requests.get(sleeping_base_url, params = params).json()
pprint(sleeping_data)
# Out:
# [{'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '2205000',
#   'cityname': 'Baton Rouge',
#   'data_value': '38.6',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '30.4510891679',
#                   'longitude': '-91.1263551997',
#                   'needs_recoding': False},
#   'high_confidence_limit': '38.8',
#   'low_confidence_limit': '38.4',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '229493',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'LA',
#   'statedesc': 'Louisiana',
#   'uniqueid': '2205000',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '2270000',
#   'cityname': 'Shreveport',
#   'data_value': '38.6',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '32.4671618864',
#                   'longitude': '-93.7962236108',
#                   'needs_recoding': False},
#   'high_confidence_limit': '38.8',
#   'low_confidence_limit': '38.4',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '199311',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'LA',
#   'statedesc': 'Louisiana',
#   'uniqueid': '2270000',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '4870808',
#   'cityname': 'Sugar Land',
#   'data_value': '31.8',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '29.5974680902',
#                   'longitude': '-95.627455775',
#                   'needs_recoding': False},
#   'high_confidence_limit': '32.2',
#   'low_confidence_limit': '31.4',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '78817',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'TX',
#   'statedesc': 'Texas',
#   'uniqueid': '4870808',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5367000',
#   'cityname': 'Spokane',
#   'data_value': '32.7',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '47.6736243259',
#                   'longitude': '-117.415973291',
#                   'needs_recoding': False},
#   'high_confidence_limit': '32.9',
#   'low_confidence_limit': '32.5',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '208916',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5367000',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0427400',
#   'cityname': 'Gilbert',
#   'data_value': '33.6',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.310149392',
#                   'longitude': '-111.746237467',
#                   'needs_recoding': False},
#   'high_confidence_limit': '33.8',
#   'low_confidence_limit': '33.4',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '208453',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0427400',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0412000',
#   'cityname': 'Chandler',
#   'data_value': '34.4',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.28318981',
#                   'longitude': '-111.852210033',
#                   'needs_recoding': False},
#   'high_confidence_limit': '34.6',
#   'low_confidence_limit': '34.2',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '236123',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0412000',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0404720',
#   'cityname': 'Avondale',
#   'data_value': '37.3',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.3858367405',
#                   'longitude': '-112.323626619',
#                   'needs_recoding': False},
#   'high_confidence_limit': '37.5',
#   'low_confidence_limit': '37.0',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '76238',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0404720',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0135896',
#   'cityname': 'Hoover',
#   'data_value': '32.8',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.3767602729',
#                   'longitude': '-86.8051937568',
#                   'needs_recoding': False},
#   'high_confidence_limit': '33.2',
#   'low_confidence_limit': '32.5',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '81619',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'AL',
#   'statedesc': 'Alabama',
#   'uniqueid': '0135896',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0150000',
#   'cityname': 'Mobile',
#   'data_value': '39.7',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '30.6776248648',
#                   'longitude': '-88.1184482714',
#                   'needs_recoding': False},
#   'high_confidence_limit': '39.9',
#   'low_confidence_limit': '39.5',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '195111',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'AL',
#   'statedesc': 'Alabama',
#   'uniqueid': '0150000',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0107000',
#   'cityname': 'Birmingham',
#   'data_value': '41.8',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.5275663773',
#                   'longitude': '-86.7988174678',
#                   'needs_recoding': False},
#   'high_confidence_limit': '42.0',
#   'low_confidence_limit': '41.7',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '212237',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'AL',
#   'statedesc': 'Alabama',
#   'uniqueid': '0107000',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0203000',
#   'cityname': 'Anchorage',
#   'data_value': '30.7',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '61.149868731',
#                   'longitude': '-149.111113424',
#                   'needs_recoding': False},
#   'high_confidence_limit': '30.9',
#   'low_confidence_limit': '30.5',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '291826',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'AK',
#   'statedesc': 'Alaska',
#   'uniqueid': '0203000',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0151000',
#   'cityname': 'Montgomery',
#   'data_value': '38.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '32.3472645333',
#                   'longitude': '-86.2677059552',
#                   'needs_recoding': False},
#   'high_confidence_limit': '38.4',
#   'low_confidence_limit': '37.9',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '205764',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'AL',
#   'statedesc': 'Alabama',
#   'uniqueid': '0151000',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0446000',
#   'cityname': 'Mesa',
#   'data_value': '36.0',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.4022837359',
#                   'longitude': '-111.718721181',
#                   'needs_recoding': False},
#   'high_confidence_limit': '36.1',
#   'low_confidence_limit': '35.9',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '439041',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0446000',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0541000',
#   'cityname': 'Little Rock',
#   'data_value': '36.4',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '34.7253957894',
#                   'longitude': '-92.3583751863',
#                   'needs_recoding': False},
#   'high_confidence_limit': '36.6',
#   'low_confidence_limit': '36.2',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '193524',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'AR',
#   'statedesc': 'Arkansas',
#   'uniqueid': '0541000',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0524550',
#   'cityname': 'Fort Smith',
#   'data_value': '35.4',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '35.3491692636',
#                   'longitude': '-94.3696317306',
#                   'needs_recoding': False},
#   'high_confidence_limit': '35.7',
#   'low_confidence_limit': '35.1',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '86209',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'AR',
#   'statedesc': 'Arkansas',
#   'uniqueid': '0524550',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0566080',
#   'cityname': 'Springdale',
#   'data_value': '36.3',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '36.1869932598',
#                   'longitude': '-94.1536274531',
#                   'needs_recoding': False},
#   'high_confidence_limit': '36.7',
#   'low_confidence_limit': '35.9',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '69797',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'AR',
#   'statedesc': 'Arkansas',
#   'uniqueid': '0566080',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0477000',
#   'cityname': 'Tucson',
#   'data_value': '34.6',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '32.1567244483',
#                   'longitude': '-110.877085494',
#                   'needs_recoding': False},
#   'high_confidence_limit': '34.8',
#   'low_confidence_limit': '34.5',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '520116',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0477000',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0485540',
#   'cityname': 'Yuma',
#   'data_value': '31.8',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '32.5986027117',
#                   'longitude': '-114.54836837',
#                   'needs_recoding': False},
#   'high_confidence_limit': '32.0',
#   'low_confidence_limit': '31.5',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '93064',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0485540',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0465000',
#   'cityname': 'Scottsdale',
#   'data_value': '32.3',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.6872493651',
#                   'longitude': '-111.865085877',
#                   'needs_recoding': False},
#   'high_confidence_limit': '32.6',
#   'low_confidence_limit': '32.1',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '217385',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0465000',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0535710',
#   'cityname': 'Jonesboro',
#   'data_value': '32.7',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '35.8208121538',
#                   'longitude': '-90.6794991686',
#                   'needs_recoding': False},
#   'high_confidence_limit': '33.2',
#   'low_confidence_limit': '32.3',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '67263',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'AR',
#   'statedesc': 'Arkansas',
#   'uniqueid': '0535710',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0523290',
#   'cityname': 'Fayetteville',
#   'data_value': '34.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '36.0712117312',
#                   'longitude': '-94.1659600436',
#                   'needs_recoding': False},
#   'high_confidence_limit': '34.9',
#   'low_confidence_limit': '34.0',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '73580',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'AR',
#   'statedesc': 'Arkansas',
#   'uniqueid': '0523290',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0602000',
#   'cityname': 'Anaheim',
#   'data_value': '33.7',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.8389076996',
#                   'longitude': '-117.857613481',
#                   'needs_recoding': False},
#   'high_confidence_limit': '33.8',
#   'low_confidence_limit': '33.5',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '336265',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0602000',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0471510',
#   'cityname': 'Surprise',
#   'data_value': '35.3',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.6803835177',
#                   'longitude': '-112.452218439',
#                   'needs_recoding': False},
#   'high_confidence_limit': '35.6',
#   'low_confidence_limit': '35.0',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '117517',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0471510',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0602252',
#   'cityname': 'Antioch',
#   'data_value': '35.4',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '37.9777042922',
#                   'longitude': '-121.796606971',
#                   'needs_recoding': False},
#   'high_confidence_limit': '35.7',
#   'low_confidence_limit': '35.2',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '102372',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0602252',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0473000',
#   'cityname': 'Tempe',
#   'data_value': '35.3',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.3882640307',
#                   'longitude': '-111.931802302',
#                   'needs_recoding': False},
#   'high_confidence_limit': '35.6',
#   'low_confidence_limit': '35.0',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '161719',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'AZ',
#   'statedesc': 'Arizona',
#   'uniqueid': '0473000',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0600884',
#   'cityname': 'Alhambra',
#   'data_value': '38.0',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '34.0839734383',
#                   'longitude': '-118.135514119',
#                   'needs_recoding': False},
#   'high_confidence_limit': '38.3',
#   'low_confidence_limit': '37.7',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '83089',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0600884',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0600562',
#   'cityname': 'Alameda',
#   'data_value': '33.7',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '37.7650849031',
#                   'longitude': '-122.266489842',
#                   'needs_recoding': False},
#   'high_confidence_limit': '34.0',
#   'low_confidence_limit': '33.3',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '73812',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0600562',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0608954',
#   'cityname': 'Burbank',
#   'data_value': '34.0',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '34.1879799605',
#                   'longitude': '-118.323429032',
#                   'needs_recoding': False},
#   'high_confidence_limit': '34.3',
#   'low_confidence_limit': '33.7',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '103340',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0608954',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0614218',
#   'cityname': 'Clovis',
#   'data_value': '33.4',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '36.8289400179',
#                   'longitude': '-119.68665285',
#                   'needs_recoding': False},
#   'high_confidence_limit': '33.7',
#   'low_confidence_limit': '33.2',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '95631',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0614218',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0613014',
#   'cityname': 'Chico',
#   'data_value': '33.4',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '39.7568503668',
#                   'longitude': '-121.815983972',
#                   'needs_recoding': False},
#   'high_confidence_limit': '33.8',
#   'low_confidence_limit': '33.0',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '86187',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0613014',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0602364',
#   'cityname': 'Apple Valley',
#   'data_value': '38.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '34.5315984948',
#                   'longitude': '-117.211012664',
#                   'needs_recoding': False},
#   'high_confidence_limit': '38.9',
#   'low_confidence_limit': '38.2',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '69135',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0602364',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0613214',
#   'cityname': 'Chino Hills',
#   'data_value': '36.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.950774546',
#                   'longitude': '-117.725326968',
#                   'needs_recoding': False},
#   'high_confidence_limit': '36.4',
#   'low_confidence_limit': '35.6',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '74799',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0613214',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0611530',
#   'cityname': 'Carson',
#   'data_value': '38.8',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.8374083001',
#                   'longitude': '-118.255936422',
#                   'needs_recoding': False},
#   'high_confidence_limit': '39.1',
#   'low_confidence_limit': '38.5',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '91714',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0611530',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0611194',
#   'cityname': 'Carlsbad',
#   'data_value': '30.2',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.1248051026',
#                   'longitude': '-117.282903303',
#                   'needs_recoding': False},
#   'high_confidence_limit': '30.5',
#   'low_confidence_limit': '29.8',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '105328',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0611194',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0613210',
#   'cityname': 'Chino',
#   'data_value': '37.4',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.983588126',
#                   'longitude': '-117.665296584',
#                   'needs_recoding': False},
#   'high_confidence_limit': '37.8',
#   'low_confidence_limit': '37.1',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '77983',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0613210',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0603526',
#   'cityname': 'Bakersfield',
#   'data_value': '36.9',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '35.3513302855',
#                   'longitude': '-119.029786003',
#                   'needs_recoding': False},
#   'high_confidence_limit': '37.1',
#   'low_confidence_limit': '36.7',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '347483',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0603526',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0613588',
#   'cityname': 'Citrus Heights',
#   'data_value': '35.6',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '38.6947788342',
#                   'longitude': '-121.287991502',
#                   'needs_recoding': False},
#   'high_confidence_limit': '35.9',
#   'low_confidence_limit': '35.3',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '83301',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0613588',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0616350',
#   'cityname': 'Corona',
#   'data_value': '37.6',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.8623571787',
#                   'longitude': '-117.564224471',
#                   'needs_recoding': False},
#   'high_confidence_limit': '37.8',
#   'low_confidence_limit': '37.4',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '152374',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0616350',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0617918',
#   'cityname': 'Daly City',
#   'data_value': '34.9',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '37.6861552276',
#                   'longitude': '-122.468298024',
#                   'needs_recoding': False},
#   'high_confidence_limit': '35.2',
#   'low_confidence_limit': '34.6',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '101123',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0617918',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0606000',
#   'cityname': 'Berkeley',
#   'data_value': '32.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '37.8725678765',
#                   'longitude': '-122.274907975',
#                   'needs_recoding': False},
#   'high_confidence_limit': '32.7',
#   'low_confidence_limit': '32.3',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '112580',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0606000',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0604982',
#   'cityname': 'Bellflower',
#   'data_value': '37.8',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.8880417923',
#                   'longitude': '-118.127100236',
#                   'needs_recoding': False},
#   'high_confidence_limit': '38.0',
#   'low_confidence_limit': '37.6',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '76616',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0604982',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0616000',
#   'cityname': 'Concord',
#   'data_value': '33.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '37.9721810307',
#                   'longitude': '-122.001588036',
#                   'needs_recoding': False},
#   'high_confidence_limit': '33.4',
#   'low_confidence_limit': '32.9',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '122067',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0616000',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0616532',
#   'cityname': 'Costa Mesa',
#   'data_value': '31.7',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.6667651353',
#                   'longitude': '-117.91350475',
#                   'needs_recoding': False},
#   'high_confidence_limit': '32.0',
#   'low_confidence_limit': '31.4',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '109960',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0616532',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0603666',
#   'cityname': 'Baldwin Park',
#   'data_value': '37.4',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '34.082871519',
#                   'longitude': '-117.972100918',
#                   'needs_recoding': False},
#   'high_confidence_limit': '37.8',
#   'low_confidence_limit': '37.1',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '75390',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0603666',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0613392',
#   'cityname': 'Chula Vista',
#   'data_value': '34.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '32.6282964262',
#                   'longitude': '-117.010042407',
#                   'needs_recoding': False},
#   'high_confidence_limit': '34.3',
#   'low_confidence_limit': '33.9',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '243916',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0613392',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0608786',
#   'cityname': 'Buena Park',
#   'data_value': '34.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.8572126844',
#                   'longitude': '-118.004517591',
#                   'needs_recoding': False},
#   'high_confidence_limit': '34.4',
#   'low_confidence_limit': '33.8',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '80530',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0608786',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0615044',
#   'cityname': 'Compton',
#   'data_value': '41.4',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.892965693',
#                   'longitude': '-118.227506568',
#                   'needs_recoding': False},
#   'high_confidence_limit': '41.6',
#   'low_confidence_limit': '41.2',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '96455',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0615044',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0622020',
#   'cityname': 'Elk Grove',
#   'data_value': '36.3',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '38.4159992006',
#                   'longitude': '-121.384137762',
#                   'needs_recoding': False},
#   'high_confidence_limit': '36.6',
#   'low_confidence_limit': '36.1',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '153015',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0622020',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0626000',
#   'cityname': 'Fremont',
#   'data_value': '34.0',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '37.5278685405',
#                   'longitude': '-121.984121512',
#                   'needs_recoding': False},
#   'high_confidence_limit': '34.2',
#   'low_confidence_limit': '33.7',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '214089',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0626000',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0627000',
#   'cityname': 'Fresno',
#   'data_value': '36.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '36.7826786711',
#                   'longitude': '-119.794126569',
#                   'needs_recoding': False},
#   'high_confidence_limit': '36.6',
#   'low_confidence_limit': '36.4',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '494665',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0627000',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0624638',
#   'cityname': 'Folsom',
#   'data_value': '33.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '38.6750494328',
#                   'longitude': '-121.147605753',
#                   'needs_recoding': False},
#   'high_confidence_limit': '33.5',
#   'low_confidence_limit': '32.7',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '72203',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0624638',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0623182',
#   'cityname': 'Fairfield',
#   'data_value': '37.4',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '38.2558446343',
#                   'longitude': '-122.039303253',
#                   'needs_recoding': False},
#   'high_confidence_limit': '37.6',
#   'low_confidence_limit': '37.2',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '105321',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0623182',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0619766',
#   'cityname': 'Downey',
#   'data_value': '35.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '33.937867256',
#                   'longitude': '-118.131150116',
#                   'needs_recoding': False},
#   'high_confidence_limit': '35.7',
#   'low_confidence_limit': '35.2',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '111772',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'CA',
#   'statedesc': 'California',
#   'uniqueid': '0619766',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '0633000',
#   'cityname': 'Hayward',
#   'data_value': '36.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
# ...
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '36.7534593339',
#                   'longitude': '-76.0589579522',
#                   'needs_recoding': False},
#   'high_confidence_limit': '37.5',
#   'low_confidence_limit': '37.2',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '437994',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'VA',
#   'statedesc': 'Virginia',
#   'uniqueid': '5182000',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5168000',
#   'cityname': 'Roanoke',
#   'data_value': '39.8',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '37.2782181855',
#                   'longitude': '-79.9581615989',
#                   'needs_recoding': False},
#   'high_confidence_limit': '40.1',
#   'low_confidence_limit': '39.5',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '97032',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'VA',
#   'statedesc': 'Virginia',
#   'uniqueid': '5168000',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5305210',
#   'cityname': 'Bellevue',
#   'data_value': '28.5',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '47.5962437606',
#                   'longitude': '-122.153569982',
#                   'needs_recoding': False},
#   'high_confidence_limit': '28.7',
#   'low_confidence_limit': '28.3',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '122363',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5305210',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5363000',
#   'cityname': 'Seattle',
#   'data_value': '29.1',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '47.622154338',
#                   'longitude': '-122.323532482',
#                   'needs_recoding': False},
#   'high_confidence_limit': '29.2',
#   'low_confidence_limit': '29.0',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '608660',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5363000',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5322640',
#   'cityname': 'Everett',
#   'data_value': '37.3',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '47.9497966189',
#                   'longitude': '-122.160703911',
#                   'needs_recoding': False},
#   'high_confidence_limit': '37.6',
#   'low_confidence_limit': '37.1',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '103019',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5322640',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5539225',
#   'cityname': 'Kenosha',
#   'data_value': '34.7',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '42.585570271',
#                   'longitude': '-87.8735745085',
#                   'needs_recoding': False},
#   'high_confidence_limit': '35.1',
#   'low_confidence_limit': '34.4',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '99218',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'WI',
#   'statedesc': 'Wisconsin',
#   'uniqueid': '5539225',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5553000',
#   'cityname': 'Milwaukee',
#   'data_value': '39.2',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '43.0641258925',
#                   'longitude': '-87.9672412429',
#                   'needs_recoding': False},
#   'high_confidence_limit': '39.3',
#   'low_confidence_limit': '39.1',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '594833',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'WI',
#   'statedesc': 'Wisconsin',
#   'uniqueid': '5553000',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5374060',
#   'cityname': 'Vancouver',
#   'data_value': '32.4',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '45.6357172365',
#                   'longitude': '-122.598539476',
#                   'needs_recoding': False},
#   'high_confidence_limit': '32.7',
#   'low_confidence_limit': '32.2',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '161791',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5374060',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5414600',
#   'cityname': 'Charleston',
#   'data_value': '40.3',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '38.3484079736',
#                   'longitude': '-81.632165003',
#                   'needs_recoding': False},
#   'high_confidence_limit': '40.7',
#   'low_confidence_limit': '40.0',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '51400',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'WV',
#   'statedesc': 'West Virginia',
#   'uniqueid': '5414600',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5502375',
#   'cityname': 'Appleton',
#   'data_value': '29.7',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '44.2776987457',
#                   'longitude': '-88.3897664444',
#                   'needs_recoding': False},
#   'high_confidence_limit': '30.1',
#   'low_confidence_limit': '29.4',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '72623',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'WI',
#   'statedesc': 'Wisconsin',
#   'uniqueid': '5502375',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5370000',
#   'cityname': 'Tacoma',
#   'data_value': '37.9',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '47.2425411445',
#                   'longitude': '-122.45447391',
#                   'needs_recoding': False},
#   'high_confidence_limit': '38.1',
#   'low_confidence_limit': '37.7',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '198397',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5370000',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5548000',
#   'cityname': 'Madison',
#   'data_value': '29.3',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '43.0809865694',
#                   'longitude': '-89.3915106344',
#                   'needs_recoding': False},
#   'high_confidence_limit': '29.5',
#   'low_confidence_limit': '29.1',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '233209',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'WI',
#   'statedesc': 'Wisconsin',
#   'uniqueid': '5548000',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5367167',
#   'cityname': 'Spokane Valley',
#   'data_value': '32.2',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '47.662556574',
#                   'longitude': '-117.234571922',
#                   'needs_recoding': False},
#   'high_confidence_limit': '32.5',
#   'low_confidence_limit': '31.9',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '89755',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5367167',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5531000',
#   'cityname': 'Green Bay',
#   'data_value': '36.0',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '44.5149847816',
#                   'longitude': '-87.9896195955',
#                   'needs_recoding': False},
#   'high_confidence_limit': '36.3',
#   'low_confidence_limit': '35.7',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '104057',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'WI',
#   'statedesc': 'Wisconsin',
#   'uniqueid': '5531000',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5380010',
#   'cityname': 'Yakima',
#   'data_value': '33.8',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '46.5925792092',
#                   'longitude': '-120.547807614',
#                   'needs_recoding': False},
#   'high_confidence_limit': '34.1',
#   'low_confidence_limit': '33.5',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '91067',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'WA',
#   'statedesc': 'Washington',
#   'uniqueid': '5380010',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5613900',
#   'cityname': 'Cheyenne',
#   'data_value': '33.4',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '41.1460804265',
#                   'longitude': '-104.789064332',
#                   'needs_recoding': False},
#   'high_confidence_limit': '33.8',
#   'low_confidence_limit': '32.9',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '59466',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'WY',
#   'statedesc': 'Wyoming',
#   'uniqueid': '5613900',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5584250',
#   'cityname': 'Waukesha',
#   'data_value': '33.2',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '43.0093332215',
#                   'longitude': '-88.2457679157',
#                   'needs_recoding': False},
#   'high_confidence_limit': '33.6',
#   'low_confidence_limit': '32.8',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '70718',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'WI',
#   'statedesc': 'Wisconsin',
#   'uniqueid': '5584250',
#   'year': '2016'},
#  {'category': 'Unhealthy Behaviors',
#   'categoryid': 'UNHBEH',
#   'cityfips': '5566000',
#   'cityname': 'Racine',
#   'data_value': '39.8',
#   'data_value_type': 'Age-adjusted prevalence',
#   'data_value_unit': '%',
#   'datasource': 'BRFSS',
#   'datavaluetypeid': 'AgeAdjPrv',
#   'geographiclevel': 'City',
#   'geolocation': {'human_address': '{"address": "", "city": "", "state": "", '
#                                    '"zip": ""}',
#                   'latitude': '42.7274599494',
#                   'longitude': '-87.813453024',
#                   'needs_recoding': False},
#   'high_confidence_limit': '40.1',
#   'low_confidence_limit': '39.4',
#   'measure': 'Sleeping less than 7 hours among adults aged >=18 Years',
#   'measureid': 'SLEEP',
#   'populationcount': '78860',
#   'short_question_text': 'Sleep <7 hours',
#   'stateabbr': 'WI',
#   'statedesc': 'Wisconsin',
#   'uniqueid': '5566000',
#   'year': '2016'}]

# %%
# Create the dataframe
sleeping_df = pd.DataFrame()
sleeping_df['City Name'] = ""
sleeping_df['% Sleep'] = ""

for x in range(len(sleeping_data)):
    sleeping_df.loc[x,'City Name'] = sleeping_data[x]['cityname']
    sleeping_df.loc[x, '% Sleep'] = sleeping_data[x]['data_value']

sleeping_df.head()
# Out:
#      City Name % Sleep
# 0  Baton Rouge    38.6
# 1   Shreveport    38.6
# 2   Sugar Land    31.8
# 3      Spokane    32.7
# 4      Gilbert    33.6

# %%
# Merge 2 datasets together
depress_sleeping_df = pd.merge(mental_df, sleeping_df, on='City Name')
depress_sleeping_df['% Depress'] = depress_sleeping_df['% Depress'].astype("float")
depress_sleeping_df['% Sleep'] = depress_sleeping_df['% Sleep'].astype("float")
depress_sleeping_df.dtypes
depress_sleeping_df.head()
# Out:
#     City Name State            Lat             Lon  % Depress  % Sleep
# 0      Mobile    AL  30.6776248648  -88.1184482714       16.3     39.7
# 1     Gilbert    AZ   33.310149392  -111.746237467       10.9     33.6
# 2    Avondale    AZ  33.3858367405  -112.323626619       13.5     37.3
# 3  Montgomery    AL  32.3472645333  -86.2677059552       15.8     38.1
# 4   Anchorage    AK   61.149868731  -149.111113424       11.0     30.7

# %%
# Add regression line
x_values = depress_sleeping_df['% Depress']
y_values = depress_sleeping_df['% Sleep']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
depress_sleeping_df.plot(kind='scatter', x='% Depress', y='% Sleep', title="% of depression population vs % of population that are sleep deprived")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(14,25),fontsize=15,color="red")
plt.savefig("Output/depressionVsSleep.jpg")
plt.show()
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: 0.6350483209947062

# %% [markdown]
# ### Comment:
# There is a moderate correlation between depression and lack of sleep. Citizens of more depressing cities also tend to sleep less than 7 hours per day.

# %% [markdown]
# ## Esther: Depress vs Physical Inactivity

# %%
# Get No Leisure time for Physical Activity data
no_leisure_url = "https://data.cdc.gov/resource/axqz-rkkp.json"
params = {
    "GeographicLevel" : "City",
    "DataValueTypeID" : "AgeAdjPrv"

}
leisure_data = requests.get(no_leisure_url, params=params).json()

print(json.dumps(leisure_data, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0877290",
#         "cityname": "Thornton",
#         "data_value": "22.0",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "39.9193994188",
#             "longitude": "-104.944956758",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "22.4",
#         "low_confidence_limit": "21.6",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "118772",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CO",
#         "statedesc": "Colorado",
#         "uniqueid": "0877290",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "2036000",
#         "cityname": "Kansas City",
#         "data_value": "39.3",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "39.1234621409",
#             "longitude": "-94.7441921112",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "39.6",
#         "low_confidence_limit": "38.9",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "145786",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "KS",
#         "statedesc": "Kansas",
#         "uniqueid": "2036000",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "2935000",
#         "cityname": "Independence",
#         "data_value": "29.8",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "39.0870794771",
#             "longitude": "-94.3502748237",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "30.3",
#         "low_confidence_limit": "29.3",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "116830",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "MO",
#         "statedesc": "Missouri",
#         "uniqueid": "2935000",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "4865000",
#         "cityname": "San Antonio",
#         "data_value": "34.8",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "29.4721475333",
#             "longitude": "-98.5246763525",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "34.9",
#         "low_confidence_limit": "34.6",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "1327407",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "TX",
#         "statedesc": "Texas",
#         "uniqueid": "4865000",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "5182000",
#         "cityname": "Virginia Beach",
#         "data_value": "23.7",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "36.7534593339",
#             "longitude": "-76.0589579522",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "23.9",
#         "low_confidence_limit": "23.4",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "437994",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "VA",
#         "statedesc": "Virginia",
#         "uniqueid": "5182000",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0412000",
#         "cityname": "Chandler",
#         "data_value": "21.3",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "33.28318981",
#             "longitude": "-111.852210033",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "21.6",
#         "low_confidence_limit": "21.0",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "236123",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "AZ",
#         "statedesc": "Arizona",
#         "uniqueid": "0412000",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0135896",
#         "cityname": "Hoover",
#         "data_value": "24.0",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "33.3767602729",
#             "longitude": "-86.8051937568",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "24.5",
#         "low_confidence_limit": "23.4",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "81619",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "AL",
#         "statedesc": "Alabama",
#         "uniqueid": "0135896",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0107000",
#         "cityname": "Birmingham",
#         "data_value": "38.1",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "33.5275663773",
#             "longitude": "-86.7988174678",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "38.5",
#         "low_confidence_limit": "37.7",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "212237",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "AL",
#         "statedesc": "Alabama",
#         "uniqueid": "0107000",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0404720",
#         "cityname": "Avondale",
#         "data_value": "28.3",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "33.3858367405",
#             "longitude": "-112.323626619",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "28.8",
#         "low_confidence_limit": "27.9",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "76238",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "AZ",
#         "statedesc": "Arizona",
#         "uniqueid": "0404720",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0150000",
#         "cityname": "Mobile",
#         "data_value": "35.7",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "30.6776248648",
#             "longitude": "-88.1184482714",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "36.1",
#         "low_confidence_limit": "35.4",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "195111",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "AL",
#         "statedesc": "Alabama",
#         "uniqueid": "0150000",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0455000",
#         "cityname": "Phoenix",
#         "data_value": "27.5",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "33.5724138695",
#             "longitude": "-112.088995222",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "27.7",
#         "low_confidence_limit": "27.4",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "1445632",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "AZ",
#         "statedesc": "Arizona",
#         "uniqueid": "0455000",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0600884",
#         "cityname": "Alhambra",
#         "data_value": "21.9",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "34.0839734383",
#             "longitude": "-118.135514119",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "22.4",
#         "low_confidence_limit": "21.5",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "83089",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CA",
#         "statedesc": "California",
#         "uniqueid": "0600884",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0524550",
#         "cityname": "Fort Smith",
#         "data_value": "37.6",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "35.3491692636",
#             "longitude": "-94.3696317306",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "38.1",
#         "low_confidence_limit": "37.0",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "86209",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "AR",
#         "statedesc": "Arkansas",
#         "uniqueid": "0524550",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0566080",
#         "cityname": "Springdale",
#         "data_value": "34.2",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "36.1869932598",
#             "longitude": "-94.1536274531",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "34.9",
#         "low_confidence_limit": "33.4",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "69797",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "AR",
#         "statedesc": "Arkansas",
#         "uniqueid": "0566080",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0477000",
#         "cityname": "Tucson",
#         "data_value": "26.9",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "32.1567244483",
#             "longitude": "-110.877085494",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "27.1",
#         "low_confidence_limit": "26.7",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "520116",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "AZ",
#         "statedesc": "Arizona",
#         "uniqueid": "0477000",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0465000",
#         "cityname": "Scottsdale",
#         "data_value": "18.2",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "33.6872493651",
#             "longitude": "-111.865085877",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "18.5",
#         "low_confidence_limit": "17.9",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "217385",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "AZ",
#         "statedesc": "Arizona",
#         "uniqueid": "0465000",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0600562",
#         "cityname": "Alameda",
#         "data_value": "16.4",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "37.7650849031",
#             "longitude": "-122.266489842",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "16.8",
#         "low_confidence_limit": "16.0",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "73812",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CA",
#         "statedesc": "California",
#         "uniqueid": "0600562",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0602000",
#         "cityname": "Anaheim",
#         "data_value": "22.6",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "33.8389076996",
#             "longitude": "-117.857613481",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "22.8",
#         "low_confidence_limit": "22.3",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "336265",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CA",
#         "statedesc": "California",
#         "uniqueid": "0602000",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0471510",
#         "cityname": "Surprise",
#         "data_value": "22.9",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "33.6803835177",
#             "longitude": "-112.452218439",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "23.4",
#         "low_confidence_limit": "22.4",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "117517",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "AZ",
#         "statedesc": "Arizona",
#         "uniqueid": "0471510",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0473000",
#         "cityname": "Tempe",
#         "data_value": "23.2",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "33.3882640307",
#             "longitude": "-111.931802302",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "23.6",
#         "low_confidence_limit": "22.8",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "161719",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "AZ",
#         "statedesc": "Arizona",
#         "uniqueid": "0473000",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0535710",
#         "cityname": "Jonesboro",
#         "data_value": "33.7",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "35.8208121538",
#             "longitude": "-90.6794991686",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "34.5",
#         "low_confidence_limit": "32.8",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "67263",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "AR",
#         "statedesc": "Arkansas",
#         "uniqueid": "0535710",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0541000",
#         "cityname": "Little Rock",
#         "data_value": "31.3",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "34.7253957894",
#             "longitude": "-92.3583751863",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "31.6",
#         "low_confidence_limit": "30.9",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "193524",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "AR",
#         "statedesc": "Arkansas",
#         "uniqueid": "0541000",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0523290",
#         "cityname": "Fayetteville",
#         "data_value": "28.0",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "36.0712117312",
#             "longitude": "-94.1659600436",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "28.9",
#         "low_confidence_limit": "27.2",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "73580",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "AR",
#         "statedesc": "Arkansas",
#         "uniqueid": "0523290",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0602252",
#         "cityname": "Antioch",
#         "data_value": "21.8",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "37.9777042922",
#             "longitude": "-121.796606971",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "22.2",
#         "low_confidence_limit": "21.5",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "102372",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CA",
#         "statedesc": "California",
#         "uniqueid": "0602252",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0485540",
#         "cityname": "Yuma",
#         "data_value": "27.2",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "32.5986027117",
#             "longitude": "-114.54836837",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "27.6",
#         "low_confidence_limit": "26.7",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "93064",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "AZ",
#         "statedesc": "Arizona",
#         "uniqueid": "0485540",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0603526",
#         "cityname": "Bakersfield",
#         "data_value": "25.6",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "35.3513302855",
#             "longitude": "-119.029786003",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "25.9",
#         "low_confidence_limit": "25.4",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "347483",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CA",
#         "statedesc": "California",
#         "uniqueid": "0603526",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0606000",
#         "cityname": "Berkeley",
#         "data_value": "15.5",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "37.8725678765",
#             "longitude": "-122.274907975",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "15.8",
#         "low_confidence_limit": "15.2",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "112580",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CA",
#         "statedesc": "California",
#         "uniqueid": "0606000",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0613210",
#         "cityname": "Chino",
#         "data_value": "23.6",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "33.983588126",
#             "longitude": "-117.665296584",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "24.1",
#         "low_confidence_limit": "23.1",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "77983",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CA",
#         "statedesc": "California",
#         "uniqueid": "0613210",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0613588",
#         "cityname": "Citrus Heights",
#         "data_value": "20.8",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "38.6947788342",
#             "longitude": "-121.287991502",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "21.3",
#         "low_confidence_limit": "20.4",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "83301",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CA",
#         "statedesc": "California",
#         "uniqueid": "0613588",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0602364",
#         "cityname": "Apple Valley",
#         "data_value": "24.9",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "34.5315984948",
#             "longitude": "-117.211012664",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "25.5",
#         "low_confidence_limit": "24.4",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "69135",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CA",
#         "statedesc": "California",
#         "uniqueid": "0602364",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0617918",
#         "cityname": "Daly City",
#         "data_value": "20.3",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "37.6861552276",
#             "longitude": "-122.468298024",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "20.7",
#         "low_confidence_limit": "19.8",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "101123",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CA",
#         "statedesc": "California",
#         "uniqueid": "0617918",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0613392",
#         "cityname": "Chula Vista",
#         "data_value": "21.4",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "32.6282964262",
#             "longitude": "-117.010042407",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "21.7",
#         "low_confidence_limit": "21.1",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "243916",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CA",
#         "statedesc": "California",
#         "uniqueid": "0613392",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0611194",
#         "cityname": "Carlsbad",
#         "data_value": "13.9",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "33.1248051026",
#             "longitude": "-117.282903303",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "14.4",
#         "low_confidence_limit": "13.5",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "105328",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CA",
#         "statedesc": "California",
#         "uniqueid": "0611194",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0604982",
#         "cityname": "Bellflower",
#         "data_value": "23.2",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "33.8880417923",
#             "longitude": "-118.127100236",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "23.6",
#         "low_confidence_limit": "22.8",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "76616",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CA",
#         "statedesc": "California",
#         "uniqueid": "0604982",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0616350",
#         "cityname": "Corona",
#         "data_value": "21.6",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "33.8623571787",
#             "longitude": "-117.564224471",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "21.9",
#         "low_confidence_limit": "21.3",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "152374",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CA",
#         "statedesc": "California",
#         "uniqueid": "0616350",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0616532",
#         "cityname": "Costa Mesa",
#         "data_value": "19.4",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "33.6667651353",
#             "longitude": "-117.91350475",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "19.8",
#         "low_confidence_limit": "19.0",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "109960",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CA",
#         "statedesc": "California",
#         "uniqueid": "0616532",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0611530",
#         "cityname": "Carson",
#         "data_value": "21.5",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "33.8374083001",
#             "longitude": "-118.255936422",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "21.9",
#         "low_confidence_limit": "21.0",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "91714",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CA",
#         "statedesc": "California",
#         "uniqueid": "0611530",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0616000",
#         "cityname": "Concord",
#         "data_value": "19.0",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "37.9721810307",
#             "longitude": "-122.001588036",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "19.4",
#         "low_confidence_limit": "18.7",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "122067",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CA",
#         "statedesc": "California",
#         "uniqueid": "0616000",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0603666",
#         "cityname": "Baldwin Park",
#         "data_value": "25.9",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "34.082871519",
#             "longitude": "-117.972100918",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "26.4",
#         "low_confidence_limit": "25.3",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "75390",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CA",
#         "statedesc": "California",
#         "uniqueid": "0603666",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0615044",
#         "cityname": "Compton",
#         "data_value": "29.3",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "33.892965693",
#             "longitude": "-118.227506568",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "29.8",
#         "low_confidence_limit": "28.9",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "96455",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CA",
#         "statedesc": "California",
#         "uniqueid": "0615044",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0608786",
#         "cityname": "Buena Park",
#         "data_value": "21.6",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "33.8572126844",
#             "longitude": "-118.004517591",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "22.0",
#         "low_confidence_limit": "21.1",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "80530",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CA",
#         "statedesc": "California",
#         "uniqueid": "0608786",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0613014",
#         "cityname": "Chico",
#         "data_value": "20.8",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "39.7568503668",
#             "longitude": "-121.815983972",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "21.2",
#         "low_confidence_limit": "20.3",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "86187",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CA",
#         "statedesc": "California",
#         "uniqueid": "0613014",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0608954",
#         "cityname": "Burbank",
#         "data_value": "17.6",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "34.1879799605",
#             "longitude": "-118.323429032",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "18.0",
#         "low_confidence_limit": "17.3",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "103340",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CA",
#         "statedesc": "California",
#         "uniqueid": "0608954",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0613214",
#         "cityname": "Chino Hills",
#         "data_value": "18.6",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "33.950774546",
#             "longitude": "-117.725326968",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "19.0",
#         "low_confidence_limit": "18.1",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "74799",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CA",
#         "statedesc": "California",
#         "uniqueid": "0613214",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0614218",
#         "cityname": "Clovis",
#         "data_value": "20.2",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "36.8289400179",
#             "longitude": "-119.68665285",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "20.5",
#         "low_confidence_limit": "19.8",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "95631",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CA",
#         "statedesc": "California",
#         "uniqueid": "0614218",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0624680",
#         "cityname": "Fontana",
#         "data_value": "26.6",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "34.0974227833",
#             "longitude": "-117.459241285",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "27.0",
#         "low_confidence_limit": "26.3",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "196069",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "CA",
#         "statedesc": "California",
#         "uniqueid": "0624680",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "0629000",
#         "cityname": "Garden Grove",
#         "data_value": "23.8",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "33.7786940635",
#             "longitude": "-117.960111162",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "24.1",
# ...
#             "latitude": "47.3090846316",
#             "longitude": "-122.335755583",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "19.7",
#         "low_confidence_limit": "19.0",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "89306",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "WA",
#         "statedesc": "Washington",
#         "uniqueid": "5323515",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "5167000",
#         "cityname": "Richmond",
#         "data_value": "29.6",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "37.5293933083",
#             "longitude": "-77.475568168",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "29.9",
#         "low_confidence_limit": "29.3",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "204214",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "VA",
#         "statedesc": "Virginia",
#         "uniqueid": "5167000",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "5548000",
#         "cityname": "Madison",
#         "data_value": "18.7",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "43.0809865694",
#             "longitude": "-89.3915106344",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "19.0",
#         "low_confidence_limit": "18.4",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "233209",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "WI",
#         "statedesc": "Wisconsin",
#         "uniqueid": "5548000",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "5380010",
#         "cityname": "Yakima",
#         "data_value": "28.6",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "46.5925792092",
#             "longitude": "-120.547807614",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "29.1",
#         "low_confidence_limit": "28.1",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "91067",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "WA",
#         "statedesc": "Washington",
#         "uniqueid": "5380010",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "5553000",
#         "cityname": "Milwaukee",
#         "data_value": "30.6",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "43.0641258925",
#             "longitude": "-87.9672412429",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "30.7",
#         "low_confidence_limit": "30.4",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "594833",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "WI",
#         "statedesc": "Wisconsin",
#         "uniqueid": "5553000",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "5502375",
#         "cityname": "Appleton",
#         "data_value": "21.7",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "44.2776987457",
#             "longitude": "-88.3897664444",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "22.3",
#         "low_confidence_limit": "21.3",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "72623",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "WI",
#         "statedesc": "Wisconsin",
#         "uniqueid": "5502375",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "5367000",
#         "cityname": "Spokane",
#         "data_value": "22.2",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "47.6736243259",
#             "longitude": "-117.415973291",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "22.5",
#         "low_confidence_limit": "21.9",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "208916",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "WA",
#         "statedesc": "Washington",
#         "uniqueid": "5367000",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "5374060",
#         "cityname": "Vancouver",
#         "data_value": "19.9",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "45.6357172365",
#             "longitude": "-122.598539476",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "20.2",
#         "low_confidence_limit": "19.6",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "161791",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "WA",
#         "statedesc": "Washington",
#         "uniqueid": "5374060",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "5367167",
#         "cityname": "Spokane Valley",
#         "data_value": "21.3",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "47.662556574",
#             "longitude": "-117.234571922",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "21.7",
#         "low_confidence_limit": "20.8",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "89755",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "WA",
#         "statedesc": "Washington",
#         "uniqueid": "5367167",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "5539225",
#         "cityname": "Kenosha",
#         "data_value": "24.6",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "42.585570271",
#             "longitude": "-87.8735745085",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "25.1",
#         "low_confidence_limit": "24.1",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "99218",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "WI",
#         "statedesc": "Wisconsin",
#         "uniqueid": "5539225",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "5531000",
#         "cityname": "Green Bay",
#         "data_value": "24.3",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "44.5149847816",
#             "longitude": "-87.9896195955",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "24.8",
#         "low_confidence_limit": "23.8",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "104057",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "WI",
#         "statedesc": "Wisconsin",
#         "uniqueid": "5531000",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "5414600",
#         "cityname": "Charleston",
#         "data_value": "28.4",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "38.3484079736",
#             "longitude": "-81.632165003",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "29.0",
#         "low_confidence_limit": "27.8",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "51400",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "WV",
#         "statedesc": "West Virginia",
#         "uniqueid": "5414600",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "5370000",
#         "cityname": "Tacoma",
#         "data_value": "22.8",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "47.2425411445",
#             "longitude": "-122.45447391",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "23.1",
#         "low_confidence_limit": "22.5",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "198397",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "WA",
#         "statedesc": "Washington",
#         "uniqueid": "5370000",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "5613900",
#         "cityname": "Cheyenne",
#         "data_value": "25.6",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "41.1460804265",
#             "longitude": "-104.789064332",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "26.2",
#         "low_confidence_limit": "24.9",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "59466",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "WY",
#         "statedesc": "Wyoming",
#         "uniqueid": "5613900",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "5566000",
#         "cityname": "Racine",
#         "data_value": "26.5",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "42.7274599494",
#             "longitude": "-87.813453024",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "27.0",
#         "low_confidence_limit": "26.1",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "78860",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "WI",
#         "statedesc": "Wisconsin",
#         "uniqueid": "5566000",
#         "year": "2017"
#     },
#     {
#         "category": "Unhealthy Behaviors",
#         "categoryid": "UNHBEH",
#         "cityfips": "5584250",
#         "cityname": "Waukesha",
#         "data_value": "21.3",
#         "data_value_type": "Age-adjusted prevalence",
#         "data_value_unit": "%",
#         "datasource": "BRFSS",
#         "datavaluetypeid": "AgeAdjPrv",
#         "geographiclevel": "City",
#         "geolocation": {
#             "human_address": "{\"address\": \"\", \"city\": \"\", \"state\": \"\", \"zip\": \"\"}",
#             "latitude": "43.0093332215",
#             "longitude": "-88.2457679157",
#             "needs_recoding": false
#         },
#         "high_confidence_limit": "21.8",
#         "low_confidence_limit": "20.7",
#         "measure": "No leisure-time physical activity among adults aged >=18 Years",
#         "measureid": "LPA",
#         "populationcount": "70718",
#         "short_question_text": "Physical Inactivity",
#         "stateabbr": "WI",
#         "statedesc": "Wisconsin",
#         "uniqueid": "5584250",
#         "year": "2017"
#     }
# ]

# %%
# Create leisure_time_df
leisure_time_df = pd.DataFrame()
leisure_time_df["City Name"] = ""
leisure_time_df["% No Leisure Time for Physical Activity"] = ""

for x in range(len(leisure_data)):
    leisure_time_df.loc[x, "City Name"] = leisure_data[x]["cityname"]
    leisure_time_df.loc[x, "% No Leisure Time for Physical Activity"] = leisure_data[x]["data_value"]

leisure_time_df.head()
# Out:
#         City Name % No Leisure Time for Physical Activity
# 0        Thornton                                    22.0
# 1     Kansas City                                    39.3
# 2    Independence                                    29.8
# 3     San Antonio                                    34.8
# 4  Virginia Beach                                    23.7

# %%
complete_df = pd.merge(mental_df, leisure_time_df, on="City Name")
complete_df["% Depress"] = complete_df["% Depress"].astype(float)
complete_df["% No Leisure Time for Physical Activity"] = complete_df["% No Leisure Time for Physical Activity"].astype(float)
complete_df.head()
# Out:
#     City Name State            Lat             Lon  % Depress  \
# 0      Mobile    AL  30.6776248648  -88.1184482714       16.3
# 1     Gilbert    AZ   33.310149392  -111.746237467       10.9
# 2    Avondale    AZ  33.3858367405  -112.323626619       13.5
# 3  Montgomery    AL  32.3472645333  -86.2677059552       15.8
# 4   Anchorage    AK   61.149868731  -149.111113424       11.0
#
#    % No Leisure Time for Physical Activity
# 0                                     35.7
# 1                                     19.6
# 2                                     28.3
# 3                                     35.1
# 4                                     21.4

# %%
#Building a scatter plot for depression values and % No Leisure Time for physical Activity
x_values = complete_df["% Depress"]
y_values = complete_df["% No Leisure Time for Physical Activity"]

slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regress_values = x_values*slope + intercept 
plt.plot(x_values, regress_values, 'r')

plt.scatter(x_values, y_values)
plt.xlabel("Depression %")
plt.ylabel("No Leisure Time for Physical Activity %")
plt.text(15,15, f"y = {round(slope,2)}x + {round(intercept, 2)}", fontsize=15, color='r')

#show plot
print(f"The r-value is {rvalue}")
plt.savefig("Output/depressionVsPhysical.jpg")
plt.show()
# Out:
# The r-value is 0.7272456795661382

# %% [markdown]
# ## Alice, Kent and Esther: Ranking the cities and states base on depression rate

# %%
# Top 5 depressing city
depress_cities = depress_drinking_df.sort_values('% Depress', ascending=False).reset_index(drop=True)
depress_cities = depress_cities.loc[0:4,['City Name','% Depress','Lat','Lon']]
depress_cities
# Out:
#     City Name  % Depress        Lat        Lon
# 0       Flint       19.6  43.023634 -83.692064
# 1     Reading       18.9  40.339968 -75.926613
# 2      Camden       18.9  39.936191 -75.107296
# 3  Youngstown       18.8  41.099329 -80.646319
# 4     Detroit       18.7  42.384702 -83.105318

# %%
# Put most depressing cities in a list
depress_cities_list = []
for x in range (5):
    depress_cities_list.append(depress_cities.loc[x,'City Name'])
print(depress_cities_list)
# Out:
# ['Flint', 'Reading', 'Camden', 'Youngstown', 'Detroit']

# %%
# Top 5 happiest city
happy_cities = depress_drinking_df.sort_values('% Depress').reset_index(drop=True)
happy_cities = happy_cities.loc[0:4,['City Name','% Depress','Lat','Lon']]
happy_cities
# Out:
#      City Name  % Depress        Lat         Lon
# 0     Plymouth        8.3  45.022463  -93.461602
# 1    Sunnyvale        8.4  37.383442 -122.025624
# 2      Fremont        8.4  37.527869 -121.984122
# 3  Johns Creek        8.5  34.033299  -84.202720
# 4    San Ramon        8.6  37.762371 -121.938150

# %%
# Put happiest cities in a list
happy_cities_list = []
for x in range (5):
    happy_cities_list.append(happy_cities.loc[x,'City Name'])
print(happy_cities_list)
# Out:
# ['Plymouth', 'Sunnyvale', 'Fremont', 'Johns Creek', 'San Ramon']

# %%
depress_cities['% Diabetes'] = ""
depress_cities['% High Blood Pressure'] = ""
depress_cities['% Kidney Disease'] = ""
depress_cities['% Cancer'] = ""
depress_cities['% Lack Insurance'] = ""
depress_cities['Type'] = "Depress"

depress_cities
# Out:
#     City Name  % Depress        Lat        Lon % Diabetes  \
# 0       Flint       19.6  43.023634 -83.692064
# 1     Reading       18.9  40.339968 -75.926613
# 2      Camden       18.9  39.936191 -75.107296
# 3  Youngstown       18.8  41.099329 -80.646319
# 4     Detroit       18.7  42.384702 -83.105318
#
#   % High Blood Pressure % Kidney Disease % Cancer % Lack Insurance     Type
# 0                                                                   Depress
# 1                                                                   Depress
# 2                                                                   Depress
# 3                                                                   Depress
# 4                                                                   Depress

# %%
diabetes_url = "https://data.cdc.gov/resource/cn78-b9bj.json?"
high_blood_pressure_url = "https://data.cdc.gov/resource/ebxs-yc6e.json?"
kidney_disease_url = "https://data.cdc.gov/resource/dnkc-3whb.json?"
cancer_url = "https://data.cdc.gov/resource/9f46-utxd.json?"
insurance_url = "https://data.cdc.gov/resource/8dbf-5cp2.json?"

for index, row in depress_cities.iterrows():
    city = depress_cities.loc[index,"City Name"]
    params['CityName']=city
    # Get diabetes data
    diabetes = requests.get(diabetes_url, params=params).json()
    depress_cities.loc[index, "% Diabetes"] = diabetes[0]['data_value']
    # Get high blood pressure data
    blood_pressure = requests.get(high_blood_pressure_url, params=params).json()
    depress_cities.loc[index, "% High Blood Pressure"] = blood_pressure[0]['data_value']
    # Get kidney disease data
    kidney_disease = requests.get(kidney_disease_url, params=params).json()
    depress_cities.loc[index, "% Kidney Disease"] = kidney_disease[0]['data_value']
    # Get cancer data
    cancer = requests.get(cancer_url, params=params).json()
    depress_cities.loc[index, "% Cancer"] = cancer[0]['data_value']
    # Get insurance data
    insurance = requests.get(insurance_url, params=params).json()
    depress_cities.loc[index, "% Lack Insurance"] = insurance[0]['data_value']


depress_cities
# Out:
#     City Name  % Depress        Lat        Lon % Diabetes  \
# 0       Flint       19.6  43.023634 -83.692064       17.2
# 1     Reading       18.9  40.339968 -75.926613       16.0
# 2      Camden       18.9  39.936191 -75.107296       20.3
# 3  Youngstown       18.8  41.099329 -80.646319       16.8
# 4     Detroit       18.7  42.384702 -83.105318       18.0
#
#   % High Blood Pressure % Kidney Disease % Cancer % Lack Insurance     Type
# 0                  45.4              4.5      6.1             17.2  Depress
# 1                  35.0              4.3      5.9             23.8  Depress
# 2                  43.5              4.6      5.3             27.6  Depress
# 3                  40.1              4.2      5.9             17.9  Depress
# 4                  46.7              4.8      5.7             19.0  Depress

# %%
happy_cities['% Diabetes'] = ""
happy_cities['% High Blood Pressure'] = ""
happy_cities['% Kidney Disease'] = ""
happy_cities['% Cancer'] = ""
happy_cities['% Lack Insurance'] = ""
happy_cities['Type'] = "Happy"

happy_cities
# Out:
#      City Name  % Depress        Lat         Lon % Diabetes  \
# 0     Plymouth        8.3  45.022463  -93.461602
# 1    Sunnyvale        8.4  37.383442 -122.025624
# 2      Fremont        8.4  37.527869 -121.984122
# 3  Johns Creek        8.5  34.033299  -84.202720
# 4    San Ramon        8.6  37.762371 -121.938150
#
#   % High Blood Pressure % Kidney Disease % Cancer % Lack Insurance   Type
# 0                                                                   Happy
# 1                                                                   Happy
# 2                                                                   Happy
# 3                                                                   Happy
# 4                                                                   Happy

# %%
for index, row in happy_cities.iterrows():
    city = happy_cities.loc[index,"City Name"]
    params['CityName']=city
    # Get diabetes data
    diabetes = requests.get(diabetes_url, params=params).json()
    happy_cities.loc[index, "% Diabetes"] = diabetes[0]['data_value']
    # Get high blood pressure data
    blood_pressure = requests.get(high_blood_pressure_url, params=params).json()
    happy_cities.loc[index, "% High Blood Pressure"] = blood_pressure[0]['data_value']
    # Get kidney disease data
    kidney_disease = requests.get(kidney_disease_url, params=params).json()
    happy_cities.loc[index, "% Kidney Disease"] = kidney_disease[0]['data_value']
    # Get cancer data
    cancer = requests.get(cancer_url, params=params).json()
    happy_cities.loc[index, "% Cancer"] = cancer[0]['data_value']
    # Get insurance data
    insurance = requests.get(insurance_url, params=params).json()
    happy_cities.loc[index, "% Lack Insurance"] = insurance[0]['data_value']


happy_cities
# Out:
#      City Name  % Depress        Lat         Lon % Diabetes  \
# 0     Plymouth        8.3  45.022463  -93.461602        5.6
# 1    Sunnyvale        8.4  37.383442 -122.025624        7.5
# 2      Fremont        8.4  37.527869 -121.984122        7.6
# 3  Johns Creek        8.5  34.033299  -84.202720        7.0
# 4    San Ramon        8.6  37.762371 -121.938150        6.6
#
#   % High Blood Pressure % Kidney Disease % Cancer % Lack Insurance   Type
# 0                  21.1              2.2      6.4              7.9  Happy
# 1                  23.7              2.3      5.6              8.4  Happy
# 2                  22.4              2.3      5.3              8.6  Happy
# 3                  23.5              2.2      6.1             13.1  Happy
# 4                  20.7              2.1      5.9              6.2  Happy

# %% [markdown]
# ### Comment:
# Cities with happier population aslo has lower percentage of diabetes, high blood pressure, kidney disease and cancer. They also more likely to have insurance. This might be because of higher awareness about heath.
# People without job cannot have insurance.

# %%
# Add 2 dataframes together and map
happy_and_depress = pd.concat([happy_cities, depress_cities])
map_plot_3 = happy_and_depress.hvplot.points(
    "Lon",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    color = "Type",
    size = 100,
    hover_cols = ['% Depress','% Diabetes','% High Blood Pressure','% Kidney Disease','% Cancer','% Lack Insurance	']
)
hvplot.save(map_plot_3, "Output/HappyAndDepress.png")
map_plot_3
# Out:
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: figure(id='p2856', ...)
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lon,Lat]   (Type,% Depress,% Diabetes,% High Blood Pressure,% Kidney Disease,% Cancer)

# %%
# States with the lowest rates of deperession based on average amount for each city listed. 
states_average = complete_df.groupby(complete_df["State"]).mean()
states_depression = states_average.sort_values("% Depress")
lowest_depression = states_depression["% Depress"].head(10)
lowest_depression
# Out:
# C:\Users\Alice Nguyen\AppData\Local\Temp\ipykernel_13032\2892370234.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   states_average = complete_df.groupby(complete_df["State"]).mean()
# State
# MN    10.230000
# HI    10.500000
# ND    10.700000
# SD    10.950000
# AK    11.000000
# DC    11.100000
# NE    11.500000
# WY    11.600000
# CO    11.870588
# CA    12.281395
# Name: % Depress, dtype: float64

# %%
#Bottom 10 States for Depression %
lowest_depression.plot(kind="bar")
plt.xlabel("States")
plt.ylabel("Depression %")
plt.title("10 Least Depressed States")
plt.show()

# %%
#Top 10 States for Depression %
highest_depression = states_average.sort_values(by="% Depress", ascending=False)
highest_depression = highest_depression["% Depress"].head(10)

highest_depression.plot(kind="bar")
plt.xlabel("States")
plt.ylabel("Depression %")
plt.title("10 Most Depressed States")
plt.show()

# %%
#Top 10 states for percentage of people with no leisure time for physical activity
highest_no_leisure = states_average.sort_values(by="% No Leisure Time for Physical Activity", ascending=False)
highest_no_leisure = highest_no_leisure["% No Leisure Time for Physical Activity"].head(10)

#Bar Graph of Data
highest_no_leisure.plot(kind="bar")
plt.xlabel("States")
plt.ylabel("No Leisure time for Physical Activity %")
plt.title("Top 10 States for No Leisure time for Physical Acti")
plt.show()
